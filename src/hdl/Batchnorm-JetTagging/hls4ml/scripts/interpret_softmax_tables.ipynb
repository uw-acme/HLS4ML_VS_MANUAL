# %%
def fixed_to_float(val: int, nfrac: int, nbits: int, signed: False) -> float:
    """Convert fixed-point integer to float."""
    if signed:
        if val & (1 << (nbits - 1)):
            val -= (1 << nbits)
            print("HELLO")
    return val / (1 << nfrac)

# %%
hex = -512
fixed_to_float(hex, nfrac=10, nbits=16, signed=True)
# Out:
# HELLO
# -64.5

# %%
0b11111_10100
# Out:
# 1012

# %%
hex = 0xda65
fixed_to_float(hex, nfrac=10, nbits=18, signed=True)
# Out:
# 54.5986328125

# %%
class ROM():
    def __init__(self, dat_path: str, input_data_fmt="16_10", address_fmt="10_4", table_data_fmt="18_10", table_data_signed=False):
        
        with open(dat_path, "r") as f:
            lines = f.readlines()
            
        self.dat = [int(line, 16) for line in lines]
        self.input_width = int(input_data_fmt.split("_")[0])
        self.input_frac = int(input_data_fmt.split("_")[1])
        self.address_width = int(address_fmt.split("_")[0])
        self.address_frac = int(address_fmt.split("_")[1])
        self.table_data_width = int(table_data_fmt.split("_")[0])
        self.table_data_frac = int(table_data_fmt.split("_")[1])
        self.table_data_signed = table_data_signed
        
    
    def _to_signed(self, val: int, width: int, n_frac:int) -> int:
        """Interpret val as a signed integer of given bit width"""
        output = val
        
        if val >= 2 ** (width - 1):
            output = val - 2 ** width
            
        output = output / (2 ** n_frac)
        return output

    def _fixed_to_float(self, val: int, total_bits: int, frac_bits: int, signed=True) -> float:
        """Convert fixed-point integer to float"""
        if signed:
            val = self._to_signed(val, total_bits, n_frac=frac_bits)
            return val
        return val / (2 ** frac_bits)

    def lookup(self, input_data: int, debug=False) -> float:
        if not isinstance(input_data, int):
            raise TypeError("input_data must be an integer. Got: {}".format(type(input_data)))

        # Interpret input as signed fixed-point
        signed_input = self._to_signed(input_data, self.input_width, self.input_frac)

        # If input is negative, interpret as fixed-point
        # If input is positive, interpret as integer (ignore fractional bits)
        if signed_input < 0:
            float_val = signed_input
            scaled_index = int(float_val * (2 ** self.address_frac))
        else:
            float_val = signed_input * 1.0  # no fractional scaling
            scaled_index = int(float_val)

        # Scale to address index
        scaled_index = int(signed_input * (2 ** self.address_frac))
        

        # Clip or wrap index to ROM size
        rom_index = scaled_index & ((1 << self.address_width) - 1)

        # Lookup value
        table_val = self.dat[rom_index]
        
        output = self._fixed_to_float(table_val, self.table_data_width, self.table_data_frac, signed=self.table_data_signed)
        
        if debug:
            print(f"Input data: {input_data}, Signed input: {signed_input}, float val: {float_val}, Scaled index: {scaled_index}, ROM index: {rom_index}, Table value: {table_val}, Output: {output}")

        # Convert output to float if needed
        return output

# %%
exp_rom: ROM = ROM(
    dat_path="/home/donovan/code/research/hls4ml/waiz-khan-files/model_7/16_10_prj/myproject_prj/solution1/impl/verilog/softmax_stable_ap_fixed_ap_fixed_16_10_5_3_0_softmax_config16_s_exp_table1_rom.dat",
    input_data_fmt="16_10",
    address_fmt="10_0",
    table_data_fmt="18_10",
    table_data_signed=False
)

print(exp_rom.lookup(0b010000_11111_00000, debug=True))
# Out:
# Input data: 17376, Signed input: 16.96875, float val: 16.96875, Scaled index: 16, ROM index: 16, Table value: 131071, Output: 127.9990234375
# 127.9990234375

# %%
# plot all the values representable by 16_10
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-2**9, 2**9)
x = x * 2 ** 6
y = [exp_rom.lookup(int(i), debug=True) for i in x]

x_proper = x / (2**10)
fig, axs = plt.subplots(1, 4, figsize=(24, 7))

# Plot with adjusted x and y limits
axs[0].plot(x_proper, y, label="Softmax exp table", marker="o", markersize=2)
axs[0].plot(x_proper, np.exp(x_proper), label="Numpy exp", color="red", alpha=0.5)
axs[0].legend()
axs[0].set_title("Softmax exp table (Adjusted Limits)")
axs[0].grid()
axs[0].set_ylim(-2, 2)
axs[0].set_xlim(-4, -1)
axs[0].set_xlabel("Input")
axs[0].set_ylabel("Output")

# Plot with current x and y limits
axs[1].plot(x_proper, y, label="Softmax exp table", marker="o", markersize=2)
axs[1].plot(x_proper, np.exp(x_proper), label="Numpy exp", color="red", alpha=0.5)
axs[1].legend()
axs[1].set_title("Softmax exp table (Current Limits)")
axs[1].grid()
axs[1].set_ylim(-5, 10)
axs[1].set_xlim(-2, 2)
axs[1].set_xlabel("Input")
axs[1].set_ylabel("Output")

# Plot with adjusted x and y limits
axs[2].plot(x_proper, y, label="Softmax exp table", marker="o", markersize=2)
axs[2].plot(x_proper, np.exp(x_proper), label="Numpy exp", color="red", alpha=0.5)
axs[2].legend()
axs[2].set_title("Softmax exp table (Adjusted Limits)")
axs[2].grid()
axs[2].set_ylim(-10, 120)
axs[2].set_xlim(-32, 32)
axs[2].set_xlabel("Input")
axs[2].set_ylabel("Output")

# Plot with adjusted x and y limits
axs[3].plot(x_proper, y, label="Softmax exp table", marker="o", markersize=2)
axs[3].plot(x_proper, np.exp(x_proper), label="Numpy exp", color="red", alpha=0.5)
axs[3].legend()
axs[3].set_title("Softmax exp table (Adjusted Limits)")
axs[3].grid()
axs[3].set_ylim(-10, 40)
axs[3].set_xlim(0, 5)
axs[3].set_xlabel("Input")
axs[3].set_ylabel("Output")

x_points = [0, 1, 2, 3, 4, 2.55859375]
y_points = np.exp(x_points)

for i, (x_val, y_val) in enumerate(zip(x_points, y_points)):
    
    for ax in axs:
        
        if ax.get_ylim()[0] <= y_val <= ax.get_ylim()[1] and ax.get_xlim()[0] <= x_val <= ax.get_xlim()[1]:
            ax.scatter(x_val, y_val, color="black", label=f"Point {i}" if i == 0 else "")
            ax.text(x_val, y_val, f"({x_val}, {y_val:.2f})", fontsize=8, color="black")

plt.tight_layout()
plt.show()
# Out:
# Input data: -32768, Signed input: -32.0, float val: -32.0, Scaled index: -32, ROM index: 992, Table value: 0, Output: 0.0
# Input data: -32704, Signed input: -31.9375, float val: -31.9375, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -32640, Signed input: -31.875, float val: -31.875, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -32576, Signed input: -31.8125, float val: -31.8125, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -32512, Signed input: -31.75, float val: -31.75, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -32448, Signed input: -31.6875, float val: -31.6875, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -32384, Signed input: -31.625, float val: -31.625, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -32320, Signed input: -31.5625, float val: -31.5625, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -32256, Signed input: -31.5, float val: -31.5, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -32192, Signed input: -31.4375, float val: -31.4375, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -32128, Signed input: -31.375, float val: -31.375, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -32064, Signed input: -31.3125, float val: -31.3125, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -32000, Signed input: -31.25, float val: -31.25, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -31936, Signed input: -31.1875, float val: -31.1875, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -31872, Signed input: -31.125, float val: -31.125, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -31808, Signed input: -31.0625, float val: -31.0625, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -31744, Signed input: -31.0, float val: -31.0, Scaled index: -31, ROM index: 993, Table value: 0, Output: 0.0
# Input data: -31680, Signed input: -30.9375, float val: -30.9375, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -31616, Signed input: -30.875, float val: -30.875, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -31552, Signed input: -30.8125, float val: -30.8125, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -31488, Signed input: -30.75, float val: -30.75, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -31424, Signed input: -30.6875, float val: -30.6875, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -31360, Signed input: -30.625, float val: -30.625, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -31296, Signed input: -30.5625, float val: -30.5625, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -31232, Signed input: -30.5, float val: -30.5, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -31168, Signed input: -30.4375, float val: -30.4375, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -31104, Signed input: -30.375, float val: -30.375, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -31040, Signed input: -30.3125, float val: -30.3125, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -30976, Signed input: -30.25, float val: -30.25, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -30912, Signed input: -30.1875, float val: -30.1875, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -30848, Signed input: -30.125, float val: -30.125, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -30784, Signed input: -30.0625, float val: -30.0625, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -30720, Signed input: -30.0, float val: -30.0, Scaled index: -30, ROM index: 994, Table value: 0, Output: 0.0
# Input data: -30656, Signed input: -29.9375, float val: -29.9375, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -30592, Signed input: -29.875, float val: -29.875, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -30528, Signed input: -29.8125, float val: -29.8125, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -30464, Signed input: -29.75, float val: -29.75, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -30400, Signed input: -29.6875, float val: -29.6875, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -30336, Signed input: -29.625, float val: -29.625, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -30272, Signed input: -29.5625, float val: -29.5625, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -30208, Signed input: -29.5, float val: -29.5, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -30144, Signed input: -29.4375, float val: -29.4375, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -30080, Signed input: -29.375, float val: -29.375, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -30016, Signed input: -29.3125, float val: -29.3125, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -29952, Signed input: -29.25, float val: -29.25, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -29888, Signed input: -29.1875, float val: -29.1875, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -29824, Signed input: -29.125, float val: -29.125, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -29760, Signed input: -29.0625, float val: -29.0625, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -29696, Signed input: -29.0, float val: -29.0, Scaled index: -29, ROM index: 995, Table value: 0, Output: 0.0
# Input data: -29632, Signed input: -28.9375, float val: -28.9375, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -29568, Signed input: -28.875, float val: -28.875, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -29504, Signed input: -28.8125, float val: -28.8125, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -29440, Signed input: -28.75, float val: -28.75, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -29376, Signed input: -28.6875, float val: -28.6875, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -29312, Signed input: -28.625, float val: -28.625, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -29248, Signed input: -28.5625, float val: -28.5625, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -29184, Signed input: -28.5, float val: -28.5, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -29120, Signed input: -28.4375, float val: -28.4375, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -29056, Signed input: -28.375, float val: -28.375, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -28992, Signed input: -28.3125, float val: -28.3125, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -28928, Signed input: -28.25, float val: -28.25, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -28864, Signed input: -28.1875, float val: -28.1875, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -28800, Signed input: -28.125, float val: -28.125, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -28736, Signed input: -28.0625, float val: -28.0625, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -28672, Signed input: -28.0, float val: -28.0, Scaled index: -28, ROM index: 996, Table value: 0, Output: 0.0
# Input data: -28608, Signed input: -27.9375, float val: -27.9375, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -28544, Signed input: -27.875, float val: -27.875, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -28480, Signed input: -27.8125, float val: -27.8125, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -28416, Signed input: -27.75, float val: -27.75, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -28352, Signed input: -27.6875, float val: -27.6875, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -28288, Signed input: -27.625, float val: -27.625, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -28224, Signed input: -27.5625, float val: -27.5625, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -28160, Signed input: -27.5, float val: -27.5, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -28096, Signed input: -27.4375, float val: -27.4375, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -28032, Signed input: -27.375, float val: -27.375, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -27968, Signed input: -27.3125, float val: -27.3125, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -27904, Signed input: -27.25, float val: -27.25, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -27840, Signed input: -27.1875, float val: -27.1875, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -27776, Signed input: -27.125, float val: -27.125, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -27712, Signed input: -27.0625, float val: -27.0625, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -27648, Signed input: -27.0, float val: -27.0, Scaled index: -27, ROM index: 997, Table value: 0, Output: 0.0
# Input data: -27584, Signed input: -26.9375, float val: -26.9375, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -27520, Signed input: -26.875, float val: -26.875, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -27456, Signed input: -26.8125, float val: -26.8125, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -27392, Signed input: -26.75, float val: -26.75, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -27328, Signed input: -26.6875, float val: -26.6875, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -27264, Signed input: -26.625, float val: -26.625, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -27200, Signed input: -26.5625, float val: -26.5625, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -27136, Signed input: -26.5, float val: -26.5, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -27072, Signed input: -26.4375, float val: -26.4375, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -27008, Signed input: -26.375, float val: -26.375, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -26944, Signed input: -26.3125, float val: -26.3125, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -26880, Signed input: -26.25, float val: -26.25, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -26816, Signed input: -26.1875, float val: -26.1875, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -26752, Signed input: -26.125, float val: -26.125, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -26688, Signed input: -26.0625, float val: -26.0625, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -26624, Signed input: -26.0, float val: -26.0, Scaled index: -26, ROM index: 998, Table value: 0, Output: 0.0
# Input data: -26560, Signed input: -25.9375, float val: -25.9375, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -26496, Signed input: -25.875, float val: -25.875, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -26432, Signed input: -25.8125, float val: -25.8125, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -26368, Signed input: -25.75, float val: -25.75, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -26304, Signed input: -25.6875, float val: -25.6875, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -26240, Signed input: -25.625, float val: -25.625, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -26176, Signed input: -25.5625, float val: -25.5625, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -26112, Signed input: -25.5, float val: -25.5, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -26048, Signed input: -25.4375, float val: -25.4375, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -25984, Signed input: -25.375, float val: -25.375, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -25920, Signed input: -25.3125, float val: -25.3125, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -25856, Signed input: -25.25, float val: -25.25, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -25792, Signed input: -25.1875, float val: -25.1875, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -25728, Signed input: -25.125, float val: -25.125, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -25664, Signed input: -25.0625, float val: -25.0625, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -25600, Signed input: -25.0, float val: -25.0, Scaled index: -25, ROM index: 999, Table value: 0, Output: 0.0
# Input data: -25536, Signed input: -24.9375, float val: -24.9375, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -25472, Signed input: -24.875, float val: -24.875, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -25408, Signed input: -24.8125, float val: -24.8125, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -25344, Signed input: -24.75, float val: -24.75, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -25280, Signed input: -24.6875, float val: -24.6875, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -25216, Signed input: -24.625, float val: -24.625, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -25152, Signed input: -24.5625, float val: -24.5625, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -25088, Signed input: -24.5, float val: -24.5, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -25024, Signed input: -24.4375, float val: -24.4375, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -24960, Signed input: -24.375, float val: -24.375, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -24896, Signed input: -24.3125, float val: -24.3125, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -24832, Signed input: -24.25, float val: -24.25, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -24768, Signed input: -24.1875, float val: -24.1875, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -24704, Signed input: -24.125, float val: -24.125, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -24640, Signed input: -24.0625, float val: -24.0625, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -24576, Signed input: -24.0, float val: -24.0, Scaled index: -24, ROM index: 1000, Table value: 0, Output: 0.0
# Input data: -24512, Signed input: -23.9375, float val: -23.9375, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -24448, Signed input: -23.875, float val: -23.875, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -24384, Signed input: -23.8125, float val: -23.8125, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -24320, Signed input: -23.75, float val: -23.75, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -24256, Signed input: -23.6875, float val: -23.6875, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -24192, Signed input: -23.625, float val: -23.625, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -24128, Signed input: -23.5625, float val: -23.5625, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -24064, Signed input: -23.5, float val: -23.5, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -24000, Signed input: -23.4375, float val: -23.4375, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -23936, Signed input: -23.375, float val: -23.375, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -23872, Signed input: -23.3125, float val: -23.3125, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -23808, Signed input: -23.25, float val: -23.25, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -23744, Signed input: -23.1875, float val: -23.1875, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -23680, Signed input: -23.125, float val: -23.125, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -23616, Signed input: -23.0625, float val: -23.0625, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -23552, Signed input: -23.0, float val: -23.0, Scaled index: -23, ROM index: 1001, Table value: 0, Output: 0.0
# Input data: -23488, Signed input: -22.9375, float val: -22.9375, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -23424, Signed input: -22.875, float val: -22.875, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -23360, Signed input: -22.8125, float val: -22.8125, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -23296, Signed input: -22.75, float val: -22.75, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -23232, Signed input: -22.6875, float val: -22.6875, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -23168, Signed input: -22.625, float val: -22.625, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -23104, Signed input: -22.5625, float val: -22.5625, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -23040, Signed input: -22.5, float val: -22.5, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -22976, Signed input: -22.4375, float val: -22.4375, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -22912, Signed input: -22.375, float val: -22.375, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -22848, Signed input: -22.3125, float val: -22.3125, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -22784, Signed input: -22.25, float val: -22.25, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -22720, Signed input: -22.1875, float val: -22.1875, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -22656, Signed input: -22.125, float val: -22.125, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -22592, Signed input: -22.0625, float val: -22.0625, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -22528, Signed input: -22.0, float val: -22.0, Scaled index: -22, ROM index: 1002, Table value: 0, Output: 0.0
# Input data: -22464, Signed input: -21.9375, float val: -21.9375, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -22400, Signed input: -21.875, float val: -21.875, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -22336, Signed input: -21.8125, float val: -21.8125, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -22272, Signed input: -21.75, float val: -21.75, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -22208, Signed input: -21.6875, float val: -21.6875, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -22144, Signed input: -21.625, float val: -21.625, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -22080, Signed input: -21.5625, float val: -21.5625, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -22016, Signed input: -21.5, float val: -21.5, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -21952, Signed input: -21.4375, float val: -21.4375, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -21888, Signed input: -21.375, float val: -21.375, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -21824, Signed input: -21.3125, float val: -21.3125, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -21760, Signed input: -21.25, float val: -21.25, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -21696, Signed input: -21.1875, float val: -21.1875, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -21632, Signed input: -21.125, float val: -21.125, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -21568, Signed input: -21.0625, float val: -21.0625, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -21504, Signed input: -21.0, float val: -21.0, Scaled index: -21, ROM index: 1003, Table value: 0, Output: 0.0
# Input data: -21440, Signed input: -20.9375, float val: -20.9375, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -21376, Signed input: -20.875, float val: -20.875, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -21312, Signed input: -20.8125, float val: -20.8125, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -21248, Signed input: -20.75, float val: -20.75, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -21184, Signed input: -20.6875, float val: -20.6875, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -21120, Signed input: -20.625, float val: -20.625, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -21056, Signed input: -20.5625, float val: -20.5625, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -20992, Signed input: -20.5, float val: -20.5, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -20928, Signed input: -20.4375, float val: -20.4375, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -20864, Signed input: -20.375, float val: -20.375, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -20800, Signed input: -20.3125, float val: -20.3125, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -20736, Signed input: -20.25, float val: -20.25, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -20672, Signed input: -20.1875, float val: -20.1875, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -20608, Signed input: -20.125, float val: -20.125, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -20544, Signed input: -20.0625, float val: -20.0625, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -20480, Signed input: -20.0, float val: -20.0, Scaled index: -20, ROM index: 1004, Table value: 0, Output: 0.0
# Input data: -20416, Signed input: -19.9375, float val: -19.9375, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -20352, Signed input: -19.875, float val: -19.875, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -20288, Signed input: -19.8125, float val: -19.8125, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -20224, Signed input: -19.75, float val: -19.75, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -20160, Signed input: -19.6875, float val: -19.6875, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -20096, Signed input: -19.625, float val: -19.625, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -20032, Signed input: -19.5625, float val: -19.5625, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -19968, Signed input: -19.5, float val: -19.5, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -19904, Signed input: -19.4375, float val: -19.4375, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -19840, Signed input: -19.375, float val: -19.375, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -19776, Signed input: -19.3125, float val: -19.3125, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -19712, Signed input: -19.25, float val: -19.25, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -19648, Signed input: -19.1875, float val: -19.1875, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -19584, Signed input: -19.125, float val: -19.125, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -19520, Signed input: -19.0625, float val: -19.0625, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -19456, Signed input: -19.0, float val: -19.0, Scaled index: -19, ROM index: 1005, Table value: 0, Output: 0.0
# Input data: -19392, Signed input: -18.9375, float val: -18.9375, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -19328, Signed input: -18.875, float val: -18.875, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -19264, Signed input: -18.8125, float val: -18.8125, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -19200, Signed input: -18.75, float val: -18.75, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -19136, Signed input: -18.6875, float val: -18.6875, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -19072, Signed input: -18.625, float val: -18.625, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -19008, Signed input: -18.5625, float val: -18.5625, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -18944, Signed input: -18.5, float val: -18.5, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -18880, Signed input: -18.4375, float val: -18.4375, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -18816, Signed input: -18.375, float val: -18.375, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -18752, Signed input: -18.3125, float val: -18.3125, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -18688, Signed input: -18.25, float val: -18.25, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -18624, Signed input: -18.1875, float val: -18.1875, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -18560, Signed input: -18.125, float val: -18.125, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -18496, Signed input: -18.0625, float val: -18.0625, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -18432, Signed input: -18.0, float val: -18.0, Scaled index: -18, ROM index: 1006, Table value: 0, Output: 0.0
# Input data: -18368, Signed input: -17.9375, float val: -17.9375, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -18304, Signed input: -17.875, float val: -17.875, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -18240, Signed input: -17.8125, float val: -17.8125, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -18176, Signed input: -17.75, float val: -17.75, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -18112, Signed input: -17.6875, float val: -17.6875, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -18048, Signed input: -17.625, float val: -17.625, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -17984, Signed input: -17.5625, float val: -17.5625, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -17920, Signed input: -17.5, float val: -17.5, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -17856, Signed input: -17.4375, float val: -17.4375, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -17792, Signed input: -17.375, float val: -17.375, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -17728, Signed input: -17.3125, float val: -17.3125, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -17664, Signed input: -17.25, float val: -17.25, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -17600, Signed input: -17.1875, float val: -17.1875, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -17536, Signed input: -17.125, float val: -17.125, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -17472, Signed input: -17.0625, float val: -17.0625, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -17408, Signed input: -17.0, float val: -17.0, Scaled index: -17, ROM index: 1007, Table value: 0, Output: 0.0
# Input data: -17344, Signed input: -16.9375, float val: -16.9375, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -17280, Signed input: -16.875, float val: -16.875, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -17216, Signed input: -16.8125, float val: -16.8125, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -17152, Signed input: -16.75, float val: -16.75, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -17088, Signed input: -16.6875, float val: -16.6875, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -17024, Signed input: -16.625, float val: -16.625, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -16960, Signed input: -16.5625, float val: -16.5625, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -16896, Signed input: -16.5, float val: -16.5, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -16832, Signed input: -16.4375, float val: -16.4375, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -16768, Signed input: -16.375, float val: -16.375, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -16704, Signed input: -16.3125, float val: -16.3125, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -16640, Signed input: -16.25, float val: -16.25, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -16576, Signed input: -16.1875, float val: -16.1875, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -16512, Signed input: -16.125, float val: -16.125, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -16448, Signed input: -16.0625, float val: -16.0625, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -16384, Signed input: -16.0, float val: -16.0, Scaled index: -16, ROM index: 1008, Table value: 0, Output: 0.0
# Input data: -16320, Signed input: -15.9375, float val: -15.9375, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -16256, Signed input: -15.875, float val: -15.875, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -16192, Signed input: -15.8125, float val: -15.8125, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -16128, Signed input: -15.75, float val: -15.75, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -16064, Signed input: -15.6875, float val: -15.6875, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -16000, Signed input: -15.625, float val: -15.625, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -15936, Signed input: -15.5625, float val: -15.5625, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -15872, Signed input: -15.5, float val: -15.5, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -15808, Signed input: -15.4375, float val: -15.4375, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -15744, Signed input: -15.375, float val: -15.375, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -15680, Signed input: -15.3125, float val: -15.3125, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -15616, Signed input: -15.25, float val: -15.25, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -15552, Signed input: -15.1875, float val: -15.1875, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -15488, Signed input: -15.125, float val: -15.125, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -15424, Signed input: -15.0625, float val: -15.0625, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -15360, Signed input: -15.0, float val: -15.0, Scaled index: -15, ROM index: 1009, Table value: 0, Output: 0.0
# Input data: -15296, Signed input: -14.9375, float val: -14.9375, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -15232, Signed input: -14.875, float val: -14.875, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -15168, Signed input: -14.8125, float val: -14.8125, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -15104, Signed input: -14.75, float val: -14.75, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -15040, Signed input: -14.6875, float val: -14.6875, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -14976, Signed input: -14.625, float val: -14.625, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -14912, Signed input: -14.5625, float val: -14.5625, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -14848, Signed input: -14.5, float val: -14.5, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -14784, Signed input: -14.4375, float val: -14.4375, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -14720, Signed input: -14.375, float val: -14.375, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -14656, Signed input: -14.3125, float val: -14.3125, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -14592, Signed input: -14.25, float val: -14.25, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -14528, Signed input: -14.1875, float val: -14.1875, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -14464, Signed input: -14.125, float val: -14.125, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -14400, Signed input: -14.0625, float val: -14.0625, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -14336, Signed input: -14.0, float val: -14.0, Scaled index: -14, ROM index: 1010, Table value: 0, Output: 0.0
# Input data: -14272, Signed input: -13.9375, float val: -13.9375, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -14208, Signed input: -13.875, float val: -13.875, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -14144, Signed input: -13.8125, float val: -13.8125, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -14080, Signed input: -13.75, float val: -13.75, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -14016, Signed input: -13.6875, float val: -13.6875, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -13952, Signed input: -13.625, float val: -13.625, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -13888, Signed input: -13.5625, float val: -13.5625, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -13824, Signed input: -13.5, float val: -13.5, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -13760, Signed input: -13.4375, float val: -13.4375, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -13696, Signed input: -13.375, float val: -13.375, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -13632, Signed input: -13.3125, float val: -13.3125, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -13568, Signed input: -13.25, float val: -13.25, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -13504, Signed input: -13.1875, float val: -13.1875, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -13440, Signed input: -13.125, float val: -13.125, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -13376, Signed input: -13.0625, float val: -13.0625, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -13312, Signed input: -13.0, float val: -13.0, Scaled index: -13, ROM index: 1011, Table value: 0, Output: 0.0
# Input data: -13248, Signed input: -12.9375, float val: -12.9375, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -13184, Signed input: -12.875, float val: -12.875, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -13120, Signed input: -12.8125, float val: -12.8125, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -13056, Signed input: -12.75, float val: -12.75, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -12992, Signed input: -12.6875, float val: -12.6875, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -12928, Signed input: -12.625, float val: -12.625, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -12864, Signed input: -12.5625, float val: -12.5625, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -12800, Signed input: -12.5, float val: -12.5, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -12736, Signed input: -12.4375, float val: -12.4375, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -12672, Signed input: -12.375, float val: -12.375, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -12608, Signed input: -12.3125, float val: -12.3125, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -12544, Signed input: -12.25, float val: -12.25, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -12480, Signed input: -12.1875, float val: -12.1875, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -12416, Signed input: -12.125, float val: -12.125, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -12352, Signed input: -12.0625, float val: -12.0625, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -12288, Signed input: -12.0, float val: -12.0, Scaled index: -12, ROM index: 1012, Table value: 0, Output: 0.0
# Input data: -12224, Signed input: -11.9375, float val: -11.9375, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -12160, Signed input: -11.875, float val: -11.875, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -12096, Signed input: -11.8125, float val: -11.8125, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -12032, Signed input: -11.75, float val: -11.75, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -11968, Signed input: -11.6875, float val: -11.6875, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -11904, Signed input: -11.625, float val: -11.625, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -11840, Signed input: -11.5625, float val: -11.5625, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -11776, Signed input: -11.5, float val: -11.5, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -11712, Signed input: -11.4375, float val: -11.4375, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -11648, Signed input: -11.375, float val: -11.375, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -11584, Signed input: -11.3125, float val: -11.3125, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -11520, Signed input: -11.25, float val: -11.25, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -11456, Signed input: -11.1875, float val: -11.1875, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -11392, Signed input: -11.125, float val: -11.125, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -11328, Signed input: -11.0625, float val: -11.0625, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -11264, Signed input: -11.0, float val: -11.0, Scaled index: -11, ROM index: 1013, Table value: 0, Output: 0.0
# Input data: -11200, Signed input: -10.9375, float val: -10.9375, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -11136, Signed input: -10.875, float val: -10.875, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -11072, Signed input: -10.8125, float val: -10.8125, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -11008, Signed input: -10.75, float val: -10.75, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -10944, Signed input: -10.6875, float val: -10.6875, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -10880, Signed input: -10.625, float val: -10.625, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -10816, Signed input: -10.5625, float val: -10.5625, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -10752, Signed input: -10.5, float val: -10.5, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -10688, Signed input: -10.4375, float val: -10.4375, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -10624, Signed input: -10.375, float val: -10.375, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -10560, Signed input: -10.3125, float val: -10.3125, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -10496, Signed input: -10.25, float val: -10.25, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -10432, Signed input: -10.1875, float val: -10.1875, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -10368, Signed input: -10.125, float val: -10.125, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -10304, Signed input: -10.0625, float val: -10.0625, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -10240, Signed input: -10.0, float val: -10.0, Scaled index: -10, ROM index: 1014, Table value: 0, Output: 0.0
# Input data: -10176, Signed input: -9.9375, float val: -9.9375, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -10112, Signed input: -9.875, float val: -9.875, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -10048, Signed input: -9.8125, float val: -9.8125, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9984, Signed input: -9.75, float val: -9.75, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9920, Signed input: -9.6875, float val: -9.6875, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9856, Signed input: -9.625, float val: -9.625, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9792, Signed input: -9.5625, float val: -9.5625, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9728, Signed input: -9.5, float val: -9.5, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9664, Signed input: -9.4375, float val: -9.4375, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9600, Signed input: -9.375, float val: -9.375, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9536, Signed input: -9.3125, float val: -9.3125, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9472, Signed input: -9.25, float val: -9.25, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9408, Signed input: -9.1875, float val: -9.1875, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9344, Signed input: -9.125, float val: -9.125, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9280, Signed input: -9.0625, float val: -9.0625, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9216, Signed input: -9.0, float val: -9.0, Scaled index: -9, ROM index: 1015, Table value: 0, Output: 0.0
# Input data: -9152, Signed input: -8.9375, float val: -8.9375, Scaled index: -8, ROM index: 1016, Table value: 0, Output: 0.0
# Input data: -9088, Signed input: -8.875, float val: -8.875, Scaled index: -8, ROM index: 1016, Table value: 0, Output: 0.0
# Input data: -9024, Signed input: -8.8125, float val: -8.8125, Scaled index: -8, ROM index: 1016, Table value: 0, Output: 0.0
# Input data: -8960, Signed input: -8.75, float val: -8.75, Scaled index: -8, ROM index: 1016, Table value: 0, Output: 0.0
# Input data: -8896, Signed input: -8.6875, float val: -8.6875, Scaled index: -8, ROM index: 1016, Table value: 0, Output: 0.0
# Input data: -8832, Signed input: -8.625, float val: -8.625, Scaled index: -8, ROM index: 1016, Table value: 0, Output: 0.0
# Input data: -8768, Signed input: -8.5625, float val: -8.5625, Scaled index: -8, ROM index: 1016, Table value: 0, Output: 0.0
# Input data: -8704, Signed input: -8.5, float val: -8.5, Scaled index: -8, ROM index: 1016, Table value: 0, Output: 0.0
# Input data: -8640, Signed input: -8.4375, float val: -8.4375, Scaled index: -8, ROM index: 1016, Table value: 0, Output: 0.0
# ...
# Input data: 25344, Signed input: 24.75, float val: 24.75, Scaled index: 24, ROM index: 24, Table value: 131071, Output: 127.9990234375
# Input data: 25408, Signed input: 24.8125, float val: 24.8125, Scaled index: 24, ROM index: 24, Table value: 131071, Output: 127.9990234375
# Input data: 25472, Signed input: 24.875, float val: 24.875, Scaled index: 24, ROM index: 24, Table value: 131071, Output: 127.9990234375
# Input data: 25536, Signed input: 24.9375, float val: 24.9375, Scaled index: 24, ROM index: 24, Table value: 131071, Output: 127.9990234375
# Input data: 25600, Signed input: 25.0, float val: 25.0, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 25664, Signed input: 25.0625, float val: 25.0625, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 25728, Signed input: 25.125, float val: 25.125, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 25792, Signed input: 25.1875, float val: 25.1875, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 25856, Signed input: 25.25, float val: 25.25, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 25920, Signed input: 25.3125, float val: 25.3125, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 25984, Signed input: 25.375, float val: 25.375, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 26048, Signed input: 25.4375, float val: 25.4375, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 26112, Signed input: 25.5, float val: 25.5, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 26176, Signed input: 25.5625, float val: 25.5625, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 26240, Signed input: 25.625, float val: 25.625, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 26304, Signed input: 25.6875, float val: 25.6875, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 26368, Signed input: 25.75, float val: 25.75, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 26432, Signed input: 25.8125, float val: 25.8125, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 26496, Signed input: 25.875, float val: 25.875, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 26560, Signed input: 25.9375, float val: 25.9375, Scaled index: 25, ROM index: 25, Table value: 131071, Output: 127.9990234375
# Input data: 26624, Signed input: 26.0, float val: 26.0, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 26688, Signed input: 26.0625, float val: 26.0625, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 26752, Signed input: 26.125, float val: 26.125, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 26816, Signed input: 26.1875, float val: 26.1875, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 26880, Signed input: 26.25, float val: 26.25, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 26944, Signed input: 26.3125, float val: 26.3125, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 27008, Signed input: 26.375, float val: 26.375, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 27072, Signed input: 26.4375, float val: 26.4375, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 27136, Signed input: 26.5, float val: 26.5, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 27200, Signed input: 26.5625, float val: 26.5625, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 27264, Signed input: 26.625, float val: 26.625, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 27328, Signed input: 26.6875, float val: 26.6875, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 27392, Signed input: 26.75, float val: 26.75, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 27456, Signed input: 26.8125, float val: 26.8125, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 27520, Signed input: 26.875, float val: 26.875, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 27584, Signed input: 26.9375, float val: 26.9375, Scaled index: 26, ROM index: 26, Table value: 131071, Output: 127.9990234375
# Input data: 27648, Signed input: 27.0, float val: 27.0, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 27712, Signed input: 27.0625, float val: 27.0625, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 27776, Signed input: 27.125, float val: 27.125, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 27840, Signed input: 27.1875, float val: 27.1875, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 27904, Signed input: 27.25, float val: 27.25, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 27968, Signed input: 27.3125, float val: 27.3125, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 28032, Signed input: 27.375, float val: 27.375, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 28096, Signed input: 27.4375, float val: 27.4375, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 28160, Signed input: 27.5, float val: 27.5, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 28224, Signed input: 27.5625, float val: 27.5625, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 28288, Signed input: 27.625, float val: 27.625, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 28352, Signed input: 27.6875, float val: 27.6875, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 28416, Signed input: 27.75, float val: 27.75, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 28480, Signed input: 27.8125, float val: 27.8125, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 28544, Signed input: 27.875, float val: 27.875, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 28608, Signed input: 27.9375, float val: 27.9375, Scaled index: 27, ROM index: 27, Table value: 131071, Output: 127.9990234375
# Input data: 28672, Signed input: 28.0, float val: 28.0, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 28736, Signed input: 28.0625, float val: 28.0625, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 28800, Signed input: 28.125, float val: 28.125, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 28864, Signed input: 28.1875, float val: 28.1875, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 28928, Signed input: 28.25, float val: 28.25, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 28992, Signed input: 28.3125, float val: 28.3125, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 29056, Signed input: 28.375, float val: 28.375, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 29120, Signed input: 28.4375, float val: 28.4375, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 29184, Signed input: 28.5, float val: 28.5, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 29248, Signed input: 28.5625, float val: 28.5625, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 29312, Signed input: 28.625, float val: 28.625, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 29376, Signed input: 28.6875, float val: 28.6875, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 29440, Signed input: 28.75, float val: 28.75, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 29504, Signed input: 28.8125, float val: 28.8125, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 29568, Signed input: 28.875, float val: 28.875, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 29632, Signed input: 28.9375, float val: 28.9375, Scaled index: 28, ROM index: 28, Table value: 131071, Output: 127.9990234375
# Input data: 29696, Signed input: 29.0, float val: 29.0, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 29760, Signed input: 29.0625, float val: 29.0625, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 29824, Signed input: 29.125, float val: 29.125, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 29888, Signed input: 29.1875, float val: 29.1875, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 29952, Signed input: 29.25, float val: 29.25, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 30016, Signed input: 29.3125, float val: 29.3125, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 30080, Signed input: 29.375, float val: 29.375, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 30144, Signed input: 29.4375, float val: 29.4375, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 30208, Signed input: 29.5, float val: 29.5, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 30272, Signed input: 29.5625, float val: 29.5625, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 30336, Signed input: 29.625, float val: 29.625, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 30400, Signed input: 29.6875, float val: 29.6875, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 30464, Signed input: 29.75, float val: 29.75, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 30528, Signed input: 29.8125, float val: 29.8125, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 30592, Signed input: 29.875, float val: 29.875, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 30656, Signed input: 29.9375, float val: 29.9375, Scaled index: 29, ROM index: 29, Table value: 131071, Output: 127.9990234375
# Input data: 30720, Signed input: 30.0, float val: 30.0, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 30784, Signed input: 30.0625, float val: 30.0625, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 30848, Signed input: 30.125, float val: 30.125, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 30912, Signed input: 30.1875, float val: 30.1875, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 30976, Signed input: 30.25, float val: 30.25, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 31040, Signed input: 30.3125, float val: 30.3125, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 31104, Signed input: 30.375, float val: 30.375, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 31168, Signed input: 30.4375, float val: 30.4375, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 31232, Signed input: 30.5, float val: 30.5, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 31296, Signed input: 30.5625, float val: 30.5625, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 31360, Signed input: 30.625, float val: 30.625, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 31424, Signed input: 30.6875, float val: 30.6875, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 31488, Signed input: 30.75, float val: 30.75, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 31552, Signed input: 30.8125, float val: 30.8125, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 31616, Signed input: 30.875, float val: 30.875, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 31680, Signed input: 30.9375, float val: 30.9375, Scaled index: 30, ROM index: 30, Table value: 131071, Output: 127.9990234375
# Input data: 31744, Signed input: 31.0, float val: 31.0, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 31808, Signed input: 31.0625, float val: 31.0625, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 31872, Signed input: 31.125, float val: 31.125, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 31936, Signed input: 31.1875, float val: 31.1875, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 32000, Signed input: 31.25, float val: 31.25, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 32064, Signed input: 31.3125, float val: 31.3125, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 32128, Signed input: 31.375, float val: 31.375, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 32192, Signed input: 31.4375, float val: 31.4375, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 32256, Signed input: 31.5, float val: 31.5, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 32320, Signed input: 31.5625, float val: 31.5625, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 32384, Signed input: 31.625, float val: 31.625, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 32448, Signed input: 31.6875, float val: 31.6875, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 32512, Signed input: 31.75, float val: 31.75, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 32576, Signed input: 31.8125, float val: 31.8125, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 32640, Signed input: 31.875, float val: 31.875, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375
# Input data: 32704, Signed input: 31.9375, float val: 31.9375, Scaled index: 31, ROM index: 31, Table value: 131071, Output: 127.9990234375

# %%
inv_rom: ROM = ROM(
    dat_path='/home/donovan/code/research/hls4ml/waiz-khan-files/model_7/16_10_prj/myproject_prj/solution1/impl/verilog/softmax_stable_ap_fixed_ap_fixed_16_10_5_3_0_softmax_config16_s_invert_table2_rom.dat',
    input_data_fmt="16_10",
    address_fmt="10_2",
    table_data_fmt="18_10",
    table_data_signed=True
)

print(inv_rom.lookup(0b000_00000_00000, debug=True))
# Out:
# Input data: 0, Signed input: 0.0, float val: 0.0, Scaled index: 0, ROM index: 0, Table value: 131071, Output: 127.9990234375
# 127.9990234375

# %%
x = np.arange(-2**9, 2**9)
x = x * 2 ** 5
y_inv = [inv_rom.lookup(int(i), debug=True) for i in x]

print("last value", y_inv[-1])

x_proper = x / (2**10)
fig, axs = plt.subplots(1, 3, figsize=(17, 5))

# Plot with adjusted x and y limits
axs[0].plot(x_proper, y_inv, label=r"RTL $1/x$ Approximation", marker="o", markersize=2, color='orange')
axs[0].plot(x_proper, 1 / (x_proper), label=r"True $1/x$", color="green", alpha=0.5)
axs[0].legend()
axs[0].set_title("RTL Inverse vs True Inverse")
axs[0].grid()
axs[0].set_ylim(-2, 2)
axs[0].set_xlim(-4, -1)
axs[0].set_xlabel("Input", fontsize=14)
axs[0].set_ylabel("Output", fontsize=14)
# make axis names fonts larger

# Plot with adjusted x and y limits
axs[1].plot(x_proper, y_inv, label=r"RTL $1/x$ Approximation", marker="o", markersize=2, color='orange')
axs[1].plot(x_proper, 1 / (x_proper), label=r"True $1/x$", color="green", alpha=0.5)
# axs[1].legend()
axs[1].legend(loc='upper right')
axs[1].set_title("RTL Inverse vs True Inverse")
axs[1].grid()
# axs[1].set_ylim(-2, 2)
# axs[1].set_xlim(-4, -1)
axs[1].set_xlabel("Input", fontsize=14)
axs[1].set_ylabel("Output", fontsize=14)

# Plot with adjusted x and y limits
axs[2].plot(x_proper, y_inv, label=r"RTL $1/x$ Approximation", marker="o", markersize=2, color='orange')
axs[2].plot(x_proper, 1 / (x_proper), label=r"True $1/x$", color="green", alpha=0.5)
axs[2].legend()
axs[2].set_title("RTL Inverse vs True Inverse")
axs[2].grid()
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-10, 10)
axs[2].set_xlabel("Input", fontsize=14)
axs[2].set_ylabel("Output", fontsize=14)

fig.savefig("scripts/output/rom_invert.png", dpi=300, bbox_inches='tight')
# Out:
# Input data: -16384, Signed input: -16.0, float val: -16.0, Scaled index: -64, ROM index: 960, Table value: 262080, Output: -0.0625
# Input data: -16352, Signed input: -15.96875, float val: -15.96875, Scaled index: -63, ROM index: 961, Table value: 262079, Output: -0.0634765625
# Input data: -16320, Signed input: -15.9375, float val: -15.9375, Scaled index: -63, ROM index: 961, Table value: 262079, Output: -0.0634765625
# Input data: -16288, Signed input: -15.90625, float val: -15.90625, Scaled index: -63, ROM index: 961, Table value: 262079, Output: -0.0634765625
# Input data: -16256, Signed input: -15.875, float val: -15.875, Scaled index: -63, ROM index: 961, Table value: 262079, Output: -0.0634765625
# Input data: -16224, Signed input: -15.84375, float val: -15.84375, Scaled index: -63, ROM index: 961, Table value: 262079, Output: -0.0634765625
# Input data: -16192, Signed input: -15.8125, float val: -15.8125, Scaled index: -63, ROM index: 961, Table value: 262079, Output: -0.0634765625
# Input data: -16160, Signed input: -15.78125, float val: -15.78125, Scaled index: -63, ROM index: 961, Table value: 262079, Output: -0.0634765625
# Input data: -16128, Signed input: -15.75, float val: -15.75, Scaled index: -63, ROM index: 961, Table value: 262079, Output: -0.0634765625
# Input data: -16096, Signed input: -15.71875, float val: -15.71875, Scaled index: -62, ROM index: 962, Table value: 262078, Output: -0.064453125
# Input data: -16064, Signed input: -15.6875, float val: -15.6875, Scaled index: -62, ROM index: 962, Table value: 262078, Output: -0.064453125
# Input data: -16032, Signed input: -15.65625, float val: -15.65625, Scaled index: -62, ROM index: 962, Table value: 262078, Output: -0.064453125
# Input data: -16000, Signed input: -15.625, float val: -15.625, Scaled index: -62, ROM index: 962, Table value: 262078, Output: -0.064453125
# Input data: -15968, Signed input: -15.59375, float val: -15.59375, Scaled index: -62, ROM index: 962, Table value: 262078, Output: -0.064453125
# Input data: -15936, Signed input: -15.5625, float val: -15.5625, Scaled index: -62, ROM index: 962, Table value: 262078, Output: -0.064453125
# Input data: -15904, Signed input: -15.53125, float val: -15.53125, Scaled index: -62, ROM index: 962, Table value: 262078, Output: -0.064453125
# Input data: -15872, Signed input: -15.5, float val: -15.5, Scaled index: -62, ROM index: 962, Table value: 262078, Output: -0.064453125
# Input data: -15840, Signed input: -15.46875, float val: -15.46875, Scaled index: -61, ROM index: 963, Table value: 262077, Output: -0.0654296875
# Input data: -15808, Signed input: -15.4375, float val: -15.4375, Scaled index: -61, ROM index: 963, Table value: 262077, Output: -0.0654296875
# Input data: -15776, Signed input: -15.40625, float val: -15.40625, Scaled index: -61, ROM index: 963, Table value: 262077, Output: -0.0654296875
# Input data: -15744, Signed input: -15.375, float val: -15.375, Scaled index: -61, ROM index: 963, Table value: 262077, Output: -0.0654296875
# Input data: -15712, Signed input: -15.34375, float val: -15.34375, Scaled index: -61, ROM index: 963, Table value: 262077, Output: -0.0654296875
# Input data: -15680, Signed input: -15.3125, float val: -15.3125, Scaled index: -61, ROM index: 963, Table value: 262077, Output: -0.0654296875
# Input data: -15648, Signed input: -15.28125, float val: -15.28125, Scaled index: -61, ROM index: 963, Table value: 262077, Output: -0.0654296875
# Input data: -15616, Signed input: -15.25, float val: -15.25, Scaled index: -61, ROM index: 963, Table value: 262077, Output: -0.0654296875
# Input data: -15584, Signed input: -15.21875, float val: -15.21875, Scaled index: -60, ROM index: 964, Table value: 262076, Output: -0.06640625
# Input data: -15552, Signed input: -15.1875, float val: -15.1875, Scaled index: -60, ROM index: 964, Table value: 262076, Output: -0.06640625
# Input data: -15520, Signed input: -15.15625, float val: -15.15625, Scaled index: -60, ROM index: 964, Table value: 262076, Output: -0.06640625
# Input data: -15488, Signed input: -15.125, float val: -15.125, Scaled index: -60, ROM index: 964, Table value: 262076, Output: -0.06640625
# Input data: -15456, Signed input: -15.09375, float val: -15.09375, Scaled index: -60, ROM index: 964, Table value: 262076, Output: -0.06640625
# Input data: -15424, Signed input: -15.0625, float val: -15.0625, Scaled index: -60, ROM index: 964, Table value: 262076, Output: -0.06640625
# Input data: -15392, Signed input: -15.03125, float val: -15.03125, Scaled index: -60, ROM index: 964, Table value: 262076, Output: -0.06640625
# Input data: -15360, Signed input: -15.0, float val: -15.0, Scaled index: -60, ROM index: 964, Table value: 262076, Output: -0.06640625
# Input data: -15328, Signed input: -14.96875, float val: -14.96875, Scaled index: -59, ROM index: 965, Table value: 262075, Output: -0.0673828125
# Input data: -15296, Signed input: -14.9375, float val: -14.9375, Scaled index: -59, ROM index: 965, Table value: 262075, Output: -0.0673828125
# Input data: -15264, Signed input: -14.90625, float val: -14.90625, Scaled index: -59, ROM index: 965, Table value: 262075, Output: -0.0673828125
# Input data: -15232, Signed input: -14.875, float val: -14.875, Scaled index: -59, ROM index: 965, Table value: 262075, Output: -0.0673828125
# Input data: -15200, Signed input: -14.84375, float val: -14.84375, Scaled index: -59, ROM index: 965, Table value: 262075, Output: -0.0673828125
# Input data: -15168, Signed input: -14.8125, float val: -14.8125, Scaled index: -59, ROM index: 965, Table value: 262075, Output: -0.0673828125
# Input data: -15136, Signed input: -14.78125, float val: -14.78125, Scaled index: -59, ROM index: 965, Table value: 262075, Output: -0.0673828125
# Input data: -15104, Signed input: -14.75, float val: -14.75, Scaled index: -59, ROM index: 965, Table value: 262075, Output: -0.0673828125
# Input data: -15072, Signed input: -14.71875, float val: -14.71875, Scaled index: -58, ROM index: 966, Table value: 262073, Output: -0.0693359375
# Input data: -15040, Signed input: -14.6875, float val: -14.6875, Scaled index: -58, ROM index: 966, Table value: 262073, Output: -0.0693359375
# Input data: -15008, Signed input: -14.65625, float val: -14.65625, Scaled index: -58, ROM index: 966, Table value: 262073, Output: -0.0693359375
# Input data: -14976, Signed input: -14.625, float val: -14.625, Scaled index: -58, ROM index: 966, Table value: 262073, Output: -0.0693359375
# Input data: -14944, Signed input: -14.59375, float val: -14.59375, Scaled index: -58, ROM index: 966, Table value: 262073, Output: -0.0693359375
# Input data: -14912, Signed input: -14.5625, float val: -14.5625, Scaled index: -58, ROM index: 966, Table value: 262073, Output: -0.0693359375
# Input data: -14880, Signed input: -14.53125, float val: -14.53125, Scaled index: -58, ROM index: 966, Table value: 262073, Output: -0.0693359375
# Input data: -14848, Signed input: -14.5, float val: -14.5, Scaled index: -58, ROM index: 966, Table value: 262073, Output: -0.0693359375
# Input data: -14816, Signed input: -14.46875, float val: -14.46875, Scaled index: -57, ROM index: 967, Table value: 262072, Output: -0.0703125
# Input data: -14784, Signed input: -14.4375, float val: -14.4375, Scaled index: -57, ROM index: 967, Table value: 262072, Output: -0.0703125
# Input data: -14752, Signed input: -14.40625, float val: -14.40625, Scaled index: -57, ROM index: 967, Table value: 262072, Output: -0.0703125
# Input data: -14720, Signed input: -14.375, float val: -14.375, Scaled index: -57, ROM index: 967, Table value: 262072, Output: -0.0703125
# Input data: -14688, Signed input: -14.34375, float val: -14.34375, Scaled index: -57, ROM index: 967, Table value: 262072, Output: -0.0703125
# Input data: -14656, Signed input: -14.3125, float val: -14.3125, Scaled index: -57, ROM index: 967, Table value: 262072, Output: -0.0703125
# Input data: -14624, Signed input: -14.28125, float val: -14.28125, Scaled index: -57, ROM index: 967, Table value: 262072, Output: -0.0703125
# Input data: -14592, Signed input: -14.25, float val: -14.25, Scaled index: -57, ROM index: 967, Table value: 262072, Output: -0.0703125
# Input data: -14560, Signed input: -14.21875, float val: -14.21875, Scaled index: -56, ROM index: 968, Table value: 262071, Output: -0.0712890625
# Input data: -14528, Signed input: -14.1875, float val: -14.1875, Scaled index: -56, ROM index: 968, Table value: 262071, Output: -0.0712890625
# Input data: -14496, Signed input: -14.15625, float val: -14.15625, Scaled index: -56, ROM index: 968, Table value: 262071, Output: -0.0712890625
# Input data: -14464, Signed input: -14.125, float val: -14.125, Scaled index: -56, ROM index: 968, Table value: 262071, Output: -0.0712890625
# Input data: -14432, Signed input: -14.09375, float val: -14.09375, Scaled index: -56, ROM index: 968, Table value: 262071, Output: -0.0712890625
# Input data: -14400, Signed input: -14.0625, float val: -14.0625, Scaled index: -56, ROM index: 968, Table value: 262071, Output: -0.0712890625
# Input data: -14368, Signed input: -14.03125, float val: -14.03125, Scaled index: -56, ROM index: 968, Table value: 262071, Output: -0.0712890625
# Input data: -14336, Signed input: -14.0, float val: -14.0, Scaled index: -56, ROM index: 968, Table value: 262071, Output: -0.0712890625
# Input data: -14304, Signed input: -13.96875, float val: -13.96875, Scaled index: -55, ROM index: 969, Table value: 262070, Output: -0.072265625
# Input data: -14272, Signed input: -13.9375, float val: -13.9375, Scaled index: -55, ROM index: 969, Table value: 262070, Output: -0.072265625
# Input data: -14240, Signed input: -13.90625, float val: -13.90625, Scaled index: -55, ROM index: 969, Table value: 262070, Output: -0.072265625
# Input data: -14208, Signed input: -13.875, float val: -13.875, Scaled index: -55, ROM index: 969, Table value: 262070, Output: -0.072265625
# Input data: -14176, Signed input: -13.84375, float val: -13.84375, Scaled index: -55, ROM index: 969, Table value: 262070, Output: -0.072265625
# Input data: -14144, Signed input: -13.8125, float val: -13.8125, Scaled index: -55, ROM index: 969, Table value: 262070, Output: -0.072265625
# Input data: -14112, Signed input: -13.78125, float val: -13.78125, Scaled index: -55, ROM index: 969, Table value: 262070, Output: -0.072265625
# Input data: -14080, Signed input: -13.75, float val: -13.75, Scaled index: -55, ROM index: 969, Table value: 262070, Output: -0.072265625
# Input data: -14048, Signed input: -13.71875, float val: -13.71875, Scaled index: -54, ROM index: 970, Table value: 262068, Output: -0.07421875
# Input data: -14016, Signed input: -13.6875, float val: -13.6875, Scaled index: -54, ROM index: 970, Table value: 262068, Output: -0.07421875
# Input data: -13984, Signed input: -13.65625, float val: -13.65625, Scaled index: -54, ROM index: 970, Table value: 262068, Output: -0.07421875
# Input data: -13952, Signed input: -13.625, float val: -13.625, Scaled index: -54, ROM index: 970, Table value: 262068, Output: -0.07421875
# Input data: -13920, Signed input: -13.59375, float val: -13.59375, Scaled index: -54, ROM index: 970, Table value: 262068, Output: -0.07421875
# Input data: -13888, Signed input: -13.5625, float val: -13.5625, Scaled index: -54, ROM index: 970, Table value: 262068, Output: -0.07421875
# Input data: -13856, Signed input: -13.53125, float val: -13.53125, Scaled index: -54, ROM index: 970, Table value: 262068, Output: -0.07421875
# Input data: -13824, Signed input: -13.5, float val: -13.5, Scaled index: -54, ROM index: 970, Table value: 262068, Output: -0.07421875
# Input data: -13792, Signed input: -13.46875, float val: -13.46875, Scaled index: -53, ROM index: 971, Table value: 262067, Output: -0.0751953125
# Input data: -13760, Signed input: -13.4375, float val: -13.4375, Scaled index: -53, ROM index: 971, Table value: 262067, Output: -0.0751953125
# Input data: -13728, Signed input: -13.40625, float val: -13.40625, Scaled index: -53, ROM index: 971, Table value: 262067, Output: -0.0751953125
# Input data: -13696, Signed input: -13.375, float val: -13.375, Scaled index: -53, ROM index: 971, Table value: 262067, Output: -0.0751953125
# Input data: -13664, Signed input: -13.34375, float val: -13.34375, Scaled index: -53, ROM index: 971, Table value: 262067, Output: -0.0751953125
# Input data: -13632, Signed input: -13.3125, float val: -13.3125, Scaled index: -53, ROM index: 971, Table value: 262067, Output: -0.0751953125
# Input data: -13600, Signed input: -13.28125, float val: -13.28125, Scaled index: -53, ROM index: 971, Table value: 262067, Output: -0.0751953125
# Input data: -13568, Signed input: -13.25, float val: -13.25, Scaled index: -53, ROM index: 971, Table value: 262067, Output: -0.0751953125
# Input data: -13536, Signed input: -13.21875, float val: -13.21875, Scaled index: -52, ROM index: 972, Table value: 262065, Output: -0.0771484375
# Input data: -13504, Signed input: -13.1875, float val: -13.1875, Scaled index: -52, ROM index: 972, Table value: 262065, Output: -0.0771484375
# Input data: -13472, Signed input: -13.15625, float val: -13.15625, Scaled index: -52, ROM index: 972, Table value: 262065, Output: -0.0771484375
# Input data: -13440, Signed input: -13.125, float val: -13.125, Scaled index: -52, ROM index: 972, Table value: 262065, Output: -0.0771484375
# Input data: -13408, Signed input: -13.09375, float val: -13.09375, Scaled index: -52, ROM index: 972, Table value: 262065, Output: -0.0771484375
# Input data: -13376, Signed input: -13.0625, float val: -13.0625, Scaled index: -52, ROM index: 972, Table value: 262065, Output: -0.0771484375
# Input data: -13344, Signed input: -13.03125, float val: -13.03125, Scaled index: -52, ROM index: 972, Table value: 262065, Output: -0.0771484375
# Input data: -13312, Signed input: -13.0, float val: -13.0, Scaled index: -52, ROM index: 972, Table value: 262065, Output: -0.0771484375
# Input data: -13280, Signed input: -12.96875, float val: -12.96875, Scaled index: -51, ROM index: 973, Table value: 262064, Output: -0.078125
# Input data: -13248, Signed input: -12.9375, float val: -12.9375, Scaled index: -51, ROM index: 973, Table value: 262064, Output: -0.078125
# Input data: -13216, Signed input: -12.90625, float val: -12.90625, Scaled index: -51, ROM index: 973, Table value: 262064, Output: -0.078125
# Input data: -13184, Signed input: -12.875, float val: -12.875, Scaled index: -51, ROM index: 973, Table value: 262064, Output: -0.078125
# Input data: -13152, Signed input: -12.84375, float val: -12.84375, Scaled index: -51, ROM index: 973, Table value: 262064, Output: -0.078125
# Input data: -13120, Signed input: -12.8125, float val: -12.8125, Scaled index: -51, ROM index: 973, Table value: 262064, Output: -0.078125
# Input data: -13088, Signed input: -12.78125, float val: -12.78125, Scaled index: -51, ROM index: 973, Table value: 262064, Output: -0.078125
# Input data: -13056, Signed input: -12.75, float val: -12.75, Scaled index: -51, ROM index: 973, Table value: 262064, Output: -0.078125
# Input data: -13024, Signed input: -12.71875, float val: -12.71875, Scaled index: -50, ROM index: 974, Table value: 262062, Output: -0.080078125
# Input data: -12992, Signed input: -12.6875, float val: -12.6875, Scaled index: -50, ROM index: 974, Table value: 262062, Output: -0.080078125
# Input data: -12960, Signed input: -12.65625, float val: -12.65625, Scaled index: -50, ROM index: 974, Table value: 262062, Output: -0.080078125
# Input data: -12928, Signed input: -12.625, float val: -12.625, Scaled index: -50, ROM index: 974, Table value: 262062, Output: -0.080078125
# Input data: -12896, Signed input: -12.59375, float val: -12.59375, Scaled index: -50, ROM index: 974, Table value: 262062, Output: -0.080078125
# Input data: -12864, Signed input: -12.5625, float val: -12.5625, Scaled index: -50, ROM index: 974, Table value: 262062, Output: -0.080078125
# Input data: -12832, Signed input: -12.53125, float val: -12.53125, Scaled index: -50, ROM index: 974, Table value: 262062, Output: -0.080078125
# Input data: -12800, Signed input: -12.5, float val: -12.5, Scaled index: -50, ROM index: 974, Table value: 262062, Output: -0.080078125
# Input data: -12768, Signed input: -12.46875, float val: -12.46875, Scaled index: -49, ROM index: 975, Table value: 262060, Output: -0.08203125
# Input data: -12736, Signed input: -12.4375, float val: -12.4375, Scaled index: -49, ROM index: 975, Table value: 262060, Output: -0.08203125
# Input data: -12704, Signed input: -12.40625, float val: -12.40625, Scaled index: -49, ROM index: 975, Table value: 262060, Output: -0.08203125
# Input data: -12672, Signed input: -12.375, float val: -12.375, Scaled index: -49, ROM index: 975, Table value: 262060, Output: -0.08203125
# Input data: -12640, Signed input: -12.34375, float val: -12.34375, Scaled index: -49, ROM index: 975, Table value: 262060, Output: -0.08203125
# Input data: -12608, Signed input: -12.3125, float val: -12.3125, Scaled index: -49, ROM index: 975, Table value: 262060, Output: -0.08203125
# Input data: -12576, Signed input: -12.28125, float val: -12.28125, Scaled index: -49, ROM index: 975, Table value: 262060, Output: -0.08203125
# Input data: -12544, Signed input: -12.25, float val: -12.25, Scaled index: -49, ROM index: 975, Table value: 262060, Output: -0.08203125
# Input data: -12512, Signed input: -12.21875, float val: -12.21875, Scaled index: -48, ROM index: 976, Table value: 262059, Output: -0.0830078125
# Input data: -12480, Signed input: -12.1875, float val: -12.1875, Scaled index: -48, ROM index: 976, Table value: 262059, Output: -0.0830078125
# Input data: -12448, Signed input: -12.15625, float val: -12.15625, Scaled index: -48, ROM index: 976, Table value: 262059, Output: -0.0830078125
# Input data: -12416, Signed input: -12.125, float val: -12.125, Scaled index: -48, ROM index: 976, Table value: 262059, Output: -0.0830078125
# Input data: -12384, Signed input: -12.09375, float val: -12.09375, Scaled index: -48, ROM index: 976, Table value: 262059, Output: -0.0830078125
# Input data: -12352, Signed input: -12.0625, float val: -12.0625, Scaled index: -48, ROM index: 976, Table value: 262059, Output: -0.0830078125
# Input data: -12320, Signed input: -12.03125, float val: -12.03125, Scaled index: -48, ROM index: 976, Table value: 262059, Output: -0.0830078125
# Input data: -12288, Signed input: -12.0, float val: -12.0, Scaled index: -48, ROM index: 976, Table value: 262059, Output: -0.0830078125
# Input data: -12256, Signed input: -11.96875, float val: -11.96875, Scaled index: -47, ROM index: 977, Table value: 262057, Output: -0.0849609375
# Input data: -12224, Signed input: -11.9375, float val: -11.9375, Scaled index: -47, ROM index: 977, Table value: 262057, Output: -0.0849609375
# Input data: -12192, Signed input: -11.90625, float val: -11.90625, Scaled index: -47, ROM index: 977, Table value: 262057, Output: -0.0849609375
# Input data: -12160, Signed input: -11.875, float val: -11.875, Scaled index: -47, ROM index: 977, Table value: 262057, Output: -0.0849609375
# Input data: -12128, Signed input: -11.84375, float val: -11.84375, Scaled index: -47, ROM index: 977, Table value: 262057, Output: -0.0849609375
# Input data: -12096, Signed input: -11.8125, float val: -11.8125, Scaled index: -47, ROM index: 977, Table value: 262057, Output: -0.0849609375
# Input data: -12064, Signed input: -11.78125, float val: -11.78125, Scaled index: -47, ROM index: 977, Table value: 262057, Output: -0.0849609375
# Input data: -12032, Signed input: -11.75, float val: -11.75, Scaled index: -47, ROM index: 977, Table value: 262057, Output: -0.0849609375
# Input data: -12000, Signed input: -11.71875, float val: -11.71875, Scaled index: -46, ROM index: 978, Table value: 262055, Output: -0.0869140625
# Input data: -11968, Signed input: -11.6875, float val: -11.6875, Scaled index: -46, ROM index: 978, Table value: 262055, Output: -0.0869140625
# Input data: -11936, Signed input: -11.65625, float val: -11.65625, Scaled index: -46, ROM index: 978, Table value: 262055, Output: -0.0869140625
# Input data: -11904, Signed input: -11.625, float val: -11.625, Scaled index: -46, ROM index: 978, Table value: 262055, Output: -0.0869140625
# Input data: -11872, Signed input: -11.59375, float val: -11.59375, Scaled index: -46, ROM index: 978, Table value: 262055, Output: -0.0869140625
# Input data: -11840, Signed input: -11.5625, float val: -11.5625, Scaled index: -46, ROM index: 978, Table value: 262055, Output: -0.0869140625
# Input data: -11808, Signed input: -11.53125, float val: -11.53125, Scaled index: -46, ROM index: 978, Table value: 262055, Output: -0.0869140625
# Input data: -11776, Signed input: -11.5, float val: -11.5, Scaled index: -46, ROM index: 978, Table value: 262055, Output: -0.0869140625
# Input data: -11744, Signed input: -11.46875, float val: -11.46875, Scaled index: -45, ROM index: 979, Table value: 262053, Output: -0.0888671875
# Input data: -11712, Signed input: -11.4375, float val: -11.4375, Scaled index: -45, ROM index: 979, Table value: 262053, Output: -0.0888671875
# Input data: -11680, Signed input: -11.40625, float val: -11.40625, Scaled index: -45, ROM index: 979, Table value: 262053, Output: -0.0888671875
# Input data: -11648, Signed input: -11.375, float val: -11.375, Scaled index: -45, ROM index: 979, Table value: 262053, Output: -0.0888671875
# Input data: -11616, Signed input: -11.34375, float val: -11.34375, Scaled index: -45, ROM index: 979, Table value: 262053, Output: -0.0888671875
# Input data: -11584, Signed input: -11.3125, float val: -11.3125, Scaled index: -45, ROM index: 979, Table value: 262053, Output: -0.0888671875
# Input data: -11552, Signed input: -11.28125, float val: -11.28125, Scaled index: -45, ROM index: 979, Table value: 262053, Output: -0.0888671875
# Input data: -11520, Signed input: -11.25, float val: -11.25, Scaled index: -45, ROM index: 979, Table value: 262053, Output: -0.0888671875
# Input data: -11488, Signed input: -11.21875, float val: -11.21875, Scaled index: -44, ROM index: 980, Table value: 262051, Output: -0.0908203125
# Input data: -11456, Signed input: -11.1875, float val: -11.1875, Scaled index: -44, ROM index: 980, Table value: 262051, Output: -0.0908203125
# Input data: -11424, Signed input: -11.15625, float val: -11.15625, Scaled index: -44, ROM index: 980, Table value: 262051, Output: -0.0908203125
# Input data: -11392, Signed input: -11.125, float val: -11.125, Scaled index: -44, ROM index: 980, Table value: 262051, Output: -0.0908203125
# Input data: -11360, Signed input: -11.09375, float val: -11.09375, Scaled index: -44, ROM index: 980, Table value: 262051, Output: -0.0908203125
# Input data: -11328, Signed input: -11.0625, float val: -11.0625, Scaled index: -44, ROM index: 980, Table value: 262051, Output: -0.0908203125
# Input data: -11296, Signed input: -11.03125, float val: -11.03125, Scaled index: -44, ROM index: 980, Table value: 262051, Output: -0.0908203125
# Input data: -11264, Signed input: -11.0, float val: -11.0, Scaled index: -44, ROM index: 980, Table value: 262051, Output: -0.0908203125
# Input data: -11232, Signed input: -10.96875, float val: -10.96875, Scaled index: -43, ROM index: 981, Table value: 262049, Output: -0.0927734375
# Input data: -11200, Signed input: -10.9375, float val: -10.9375, Scaled index: -43, ROM index: 981, Table value: 262049, Output: -0.0927734375
# Input data: -11168, Signed input: -10.90625, float val: -10.90625, Scaled index: -43, ROM index: 981, Table value: 262049, Output: -0.0927734375
# Input data: -11136, Signed input: -10.875, float val: -10.875, Scaled index: -43, ROM index: 981, Table value: 262049, Output: -0.0927734375
# Input data: -11104, Signed input: -10.84375, float val: -10.84375, Scaled index: -43, ROM index: 981, Table value: 262049, Output: -0.0927734375
# Input data: -11072, Signed input: -10.8125, float val: -10.8125, Scaled index: -43, ROM index: 981, Table value: 262049, Output: -0.0927734375
# Input data: -11040, Signed input: -10.78125, float val: -10.78125, Scaled index: -43, ROM index: 981, Table value: 262049, Output: -0.0927734375
# Input data: -11008, Signed input: -10.75, float val: -10.75, Scaled index: -43, ROM index: 981, Table value: 262049, Output: -0.0927734375
# Input data: -10976, Signed input: -10.71875, float val: -10.71875, Scaled index: -42, ROM index: 982, Table value: 262046, Output: -0.095703125
# Input data: -10944, Signed input: -10.6875, float val: -10.6875, Scaled index: -42, ROM index: 982, Table value: 262046, Output: -0.095703125
# Input data: -10912, Signed input: -10.65625, float val: -10.65625, Scaled index: -42, ROM index: 982, Table value: 262046, Output: -0.095703125
# Input data: -10880, Signed input: -10.625, float val: -10.625, Scaled index: -42, ROM index: 982, Table value: 262046, Output: -0.095703125
# Input data: -10848, Signed input: -10.59375, float val: -10.59375, Scaled index: -42, ROM index: 982, Table value: 262046, Output: -0.095703125
# Input data: -10816, Signed input: -10.5625, float val: -10.5625, Scaled index: -42, ROM index: 982, Table value: 262046, Output: -0.095703125
# Input data: -10784, Signed input: -10.53125, float val: -10.53125, Scaled index: -42, ROM index: 982, Table value: 262046, Output: -0.095703125
# Input data: -10752, Signed input: -10.5, float val: -10.5, Scaled index: -42, ROM index: 982, Table value: 262046, Output: -0.095703125
# Input data: -10720, Signed input: -10.46875, float val: -10.46875, Scaled index: -41, ROM index: 983, Table value: 262044, Output: -0.09765625
# Input data: -10688, Signed input: -10.4375, float val: -10.4375, Scaled index: -41, ROM index: 983, Table value: 262044, Output: -0.09765625
# Input data: -10656, Signed input: -10.40625, float val: -10.40625, Scaled index: -41, ROM index: 983, Table value: 262044, Output: -0.09765625
# Input data: -10624, Signed input: -10.375, float val: -10.375, Scaled index: -41, ROM index: 983, Table value: 262044, Output: -0.09765625
# Input data: -10592, Signed input: -10.34375, float val: -10.34375, Scaled index: -41, ROM index: 983, Table value: 262044, Output: -0.09765625
# Input data: -10560, Signed input: -10.3125, float val: -10.3125, Scaled index: -41, ROM index: 983, Table value: 262044, Output: -0.09765625
# Input data: -10528, Signed input: -10.28125, float val: -10.28125, Scaled index: -41, ROM index: 983, Table value: 262044, Output: -0.09765625
# Input data: -10496, Signed input: -10.25, float val: -10.25, Scaled index: -41, ROM index: 983, Table value: 262044, Output: -0.09765625
# Input data: -10464, Signed input: -10.21875, float val: -10.21875, Scaled index: -40, ROM index: 984, Table value: 262042, Output: -0.099609375
# Input data: -10432, Signed input: -10.1875, float val: -10.1875, Scaled index: -40, ROM index: 984, Table value: 262042, Output: -0.099609375
# Input data: -10400, Signed input: -10.15625, float val: -10.15625, Scaled index: -40, ROM index: 984, Table value: 262042, Output: -0.099609375
# Input data: -10368, Signed input: -10.125, float val: -10.125, Scaled index: -40, ROM index: 984, Table value: 262042, Output: -0.099609375
# Input data: -10336, Signed input: -10.09375, float val: -10.09375, Scaled index: -40, ROM index: 984, Table value: 262042, Output: -0.099609375
# Input data: -10304, Signed input: -10.0625, float val: -10.0625, Scaled index: -40, ROM index: 984, Table value: 262042, Output: -0.099609375
# Input data: -10272, Signed input: -10.03125, float val: -10.03125, Scaled index: -40, ROM index: 984, Table value: 262042, Output: -0.099609375
# Input data: -10240, Signed input: -10.0, float val: -10.0, Scaled index: -40, ROM index: 984, Table value: 262042, Output: -0.099609375
# Input data: -10208, Signed input: -9.96875, float val: -9.96875, Scaled index: -39, ROM index: 985, Table value: 262039, Output: -0.1025390625
# Input data: -10176, Signed input: -9.9375, float val: -9.9375, Scaled index: -39, ROM index: 985, Table value: 262039, Output: -0.1025390625
# Input data: -10144, Signed input: -9.90625, float val: -9.90625, Scaled index: -39, ROM index: 985, Table value: 262039, Output: -0.1025390625
# Input data: -10112, Signed input: -9.875, float val: -9.875, Scaled index: -39, ROM index: 985, Table value: 262039, Output: -0.1025390625
# Input data: -10080, Signed input: -9.84375, float val: -9.84375, Scaled index: -39, ROM index: 985, Table value: 262039, Output: -0.1025390625
# Input data: -10048, Signed input: -9.8125, float val: -9.8125, Scaled index: -39, ROM index: 985, Table value: 262039, Output: -0.1025390625
# Input data: -10016, Signed input: -9.78125, float val: -9.78125, Scaled index: -39, ROM index: 985, Table value: 262039, Output: -0.1025390625
# Input data: -9984, Signed input: -9.75, float val: -9.75, Scaled index: -39, ROM index: 985, Table value: 262039, Output: -0.1025390625
# Input data: -9952, Signed input: -9.71875, float val: -9.71875, Scaled index: -38, ROM index: 986, Table value: 262036, Output: -0.10546875
# Input data: -9920, Signed input: -9.6875, float val: -9.6875, Scaled index: -38, ROM index: 986, Table value: 262036, Output: -0.10546875
# Input data: -9888, Signed input: -9.65625, float val: -9.65625, Scaled index: -38, ROM index: 986, Table value: 262036, Output: -0.10546875
# Input data: -9856, Signed input: -9.625, float val: -9.625, Scaled index: -38, ROM index: 986, Table value: 262036, Output: -0.10546875
# Input data: -9824, Signed input: -9.59375, float val: -9.59375, Scaled index: -38, ROM index: 986, Table value: 262036, Output: -0.10546875
# Input data: -9792, Signed input: -9.5625, float val: -9.5625, Scaled index: -38, ROM index: 986, Table value: 262036, Output: -0.10546875
# Input data: -9760, Signed input: -9.53125, float val: -9.53125, Scaled index: -38, ROM index: 986, Table value: 262036, Output: -0.10546875
# Input data: -9728, Signed input: -9.5, float val: -9.5, Scaled index: -38, ROM index: 986, Table value: 262036, Output: -0.10546875
# Input data: -9696, Signed input: -9.46875, float val: -9.46875, Scaled index: -37, ROM index: 987, Table value: 262033, Output: -0.1083984375
# Input data: -9664, Signed input: -9.4375, float val: -9.4375, Scaled index: -37, ROM index: 987, Table value: 262033, Output: -0.1083984375
# Input data: -9632, Signed input: -9.40625, float val: -9.40625, Scaled index: -37, ROM index: 987, Table value: 262033, Output: -0.1083984375
# Input data: -9600, Signed input: -9.375, float val: -9.375, Scaled index: -37, ROM index: 987, Table value: 262033, Output: -0.1083984375
# Input data: -9568, Signed input: -9.34375, float val: -9.34375, Scaled index: -37, ROM index: 987, Table value: 262033, Output: -0.1083984375
# Input data: -9536, Signed input: -9.3125, float val: -9.3125, Scaled index: -37, ROM index: 987, Table value: 262033, Output: -0.1083984375
# Input data: -9504, Signed input: -9.28125, float val: -9.28125, Scaled index: -37, ROM index: 987, Table value: 262033, Output: -0.1083984375
# Input data: -9472, Signed input: -9.25, float val: -9.25, Scaled index: -37, ROM index: 987, Table value: 262033, Output: -0.1083984375
# Input data: -9440, Signed input: -9.21875, float val: -9.21875, Scaled index: -36, ROM index: 988, Table value: 262030, Output: -0.111328125
# Input data: -9408, Signed input: -9.1875, float val: -9.1875, Scaled index: -36, ROM index: 988, Table value: 262030, Output: -0.111328125
# Input data: -9376, Signed input: -9.15625, float val: -9.15625, Scaled index: -36, ROM index: 988, Table value: 262030, Output: -0.111328125
# Input data: -9344, Signed input: -9.125, float val: -9.125, Scaled index: -36, ROM index: 988, Table value: 262030, Output: -0.111328125
# Input data: -9312, Signed input: -9.09375, float val: -9.09375, Scaled index: -36, ROM index: 988, Table value: 262030, Output: -0.111328125
# Input data: -9280, Signed input: -9.0625, float val: -9.0625, Scaled index: -36, ROM index: 988, Table value: 262030, Output: -0.111328125
# Input data: -9248, Signed input: -9.03125, float val: -9.03125, Scaled index: -36, ROM index: 988, Table value: 262030, Output: -0.111328125
# Input data: -9216, Signed input: -9.0, float val: -9.0, Scaled index: -36, ROM index: 988, Table value: 262030, Output: -0.111328125
# Input data: -9184, Signed input: -8.96875, float val: -8.96875, Scaled index: -35, ROM index: 989, Table value: 262027, Output: -0.1142578125
# Input data: -9152, Signed input: -8.9375, float val: -8.9375, Scaled index: -35, ROM index: 989, Table value: 262027, Output: -0.1142578125
# Input data: -9120, Signed input: -8.90625, float val: -8.90625, Scaled index: -35, ROM index: 989, Table value: 262027, Output: -0.1142578125
# Input data: -9088, Signed input: -8.875, float val: -8.875, Scaled index: -35, ROM index: 989, Table value: 262027, Output: -0.1142578125
# Input data: -9056, Signed input: -8.84375, float val: -8.84375, Scaled index: -35, ROM index: 989, Table value: 262027, Output: -0.1142578125
# Input data: -9024, Signed input: -8.8125, float val: -8.8125, Scaled index: -35, ROM index: 989, Table value: 262027, Output: -0.1142578125
# Input data: -8992, Signed input: -8.78125, float val: -8.78125, Scaled index: -35, ROM index: 989, Table value: 262027, Output: -0.1142578125
# Input data: -8960, Signed input: -8.75, float val: -8.75, Scaled index: -35, ROM index: 989, Table value: 262027, Output: -0.1142578125
# Input data: -8928, Signed input: -8.71875, float val: -8.71875, Scaled index: -34, ROM index: 990, Table value: 262024, Output: -0.1171875
# Input data: -8896, Signed input: -8.6875, float val: -8.6875, Scaled index: -34, ROM index: 990, Table value: 262024, Output: -0.1171875
# Input data: -8864, Signed input: -8.65625, float val: -8.65625, Scaled index: -34, ROM index: 990, Table value: 262024, Output: -0.1171875
# Input data: -8832, Signed input: -8.625, float val: -8.625, Scaled index: -34, ROM index: 990, Table value: 262024, Output: -0.1171875
# Input data: -8800, Signed input: -8.59375, float val: -8.59375, Scaled index: -34, ROM index: 990, Table value: 262024, Output: -0.1171875
# Input data: -8768, Signed input: -8.5625, float val: -8.5625, Scaled index: -34, ROM index: 990, Table value: 262024, Output: -0.1171875
# Input data: -8736, Signed input: -8.53125, float val: -8.53125, Scaled index: -34, ROM index: 990, Table value: 262024, Output: -0.1171875
# Input data: -8704, Signed input: -8.5, float val: -8.5, Scaled index: -34, ROM index: 990, Table value: 262024, Output: -0.1171875
# Input data: -8672, Signed input: -8.46875, float val: -8.46875, Scaled index: -33, ROM index: 991, Table value: 262020, Output: -0.12109375
# Input data: -8640, Signed input: -8.4375, float val: -8.4375, Scaled index: -33, ROM index: 991, Table value: 262020, Output: -0.12109375
# Input data: -8608, Signed input: -8.40625, float val: -8.40625, Scaled index: -33, ROM index: 991, Table value: 262020, Output: -0.12109375
# Input data: -8576, Signed input: -8.375, float val: -8.375, Scaled index: -33, ROM index: 991, Table value: 262020, Output: -0.12109375
# Input data: -8544, Signed input: -8.34375, float val: -8.34375, Scaled index: -33, ROM index: 991, Table value: 262020, Output: -0.12109375
# Input data: -8512, Signed input: -8.3125, float val: -8.3125, Scaled index: -33, ROM index: 991, Table value: 262020, Output: -0.12109375
# Input data: -8480, Signed input: -8.28125, float val: -8.28125, Scaled index: -33, ROM index: 991, Table value: 262020, Output: -0.12109375
# Input data: -8448, Signed input: -8.25, float val: -8.25, Scaled index: -33, ROM index: 991, Table value: 262020, Output: -0.12109375
# Input data: -8416, Signed input: -8.21875, float val: -8.21875, Scaled index: -32, ROM index: 992, Table value: 262016, Output: -0.125
# Input data: -8384, Signed input: -8.1875, float val: -8.1875, Scaled index: -32, ROM index: 992, Table value: 262016, Output: -0.125
# Input data: -8352, Signed input: -8.15625, float val: -8.15625, Scaled index: -32, ROM index: 992, Table value: 262016, Output: -0.125
# Input data: -8320, Signed input: -8.125, float val: -8.125, Scaled index: -32, ROM index: 992, Table value: 262016, Output: -0.125
# Input data: -8288, Signed input: -8.09375, float val: -8.09375, Scaled index: -32, ROM index: 992, Table value: 262016, Output: -0.125
# Input data: -8256, Signed input: -8.0625, float val: -8.0625, Scaled index: -32, ROM index: 992, Table value: 262016, Output: -0.125
# Input data: -8224, Signed input: -8.03125, float val: -8.03125, Scaled index: -32, ROM index: 992, Table value: 262016, Output: -0.125
# Input data: -8192, Signed input: -8.0, float val: -8.0, Scaled index: -32, ROM index: 992, Table value: 262016, Output: -0.125
# Input data: -8160, Signed input: -7.96875, float val: -7.96875, Scaled index: -31, ROM index: 993, Table value: 262012, Output: -0.12890625
# Input data: -8128, Signed input: -7.9375, float val: -7.9375, Scaled index: -31, ROM index: 993, Table value: 262012, Output: -0.12890625
# Input data: -8096, Signed input: -7.90625, float val: -7.90625, Scaled index: -31, ROM index: 993, Table value: 262012, Output: -0.12890625
# Input data: -8064, Signed input: -7.875, float val: -7.875, Scaled index: -31, ROM index: 993, Table value: 262012, Output: -0.12890625
# Input data: -8032, Signed input: -7.84375, float val: -7.84375, Scaled index: -31, ROM index: 993, Table value: 262012, Output: -0.12890625
# Input data: -8000, Signed input: -7.8125, float val: -7.8125, Scaled index: -31, ROM index: 993, Table value: 262012, Output: -0.12890625
# Input data: -7968, Signed input: -7.78125, float val: -7.78125, Scaled index: -31, ROM index: 993, Table value: 262012, Output: -0.12890625
# Input data: -7936, Signed input: -7.75, float val: -7.75, Scaled index: -31, ROM index: 993, Table value: 262012, Output: -0.12890625
# Input data: -7904, Signed input: -7.71875, float val: -7.71875, Scaled index: -30, ROM index: 994, Table value: 262007, Output: -0.1337890625
# Input data: -7872, Signed input: -7.6875, float val: -7.6875, Scaled index: -30, ROM index: 994, Table value: 262007, Output: -0.1337890625
# Input data: -7840, Signed input: -7.65625, float val: -7.65625, Scaled index: -30, ROM index: 994, Table value: 262007, Output: -0.1337890625
# Input data: -7808, Signed input: -7.625, float val: -7.625, Scaled index: -30, ROM index: 994, Table value: 262007, Output: -0.1337890625
# Input data: -7776, Signed input: -7.59375, float val: -7.59375, Scaled index: -30, ROM index: 994, Table value: 262007, Output: -0.1337890625
# Input data: -7744, Signed input: -7.5625, float val: -7.5625, Scaled index: -30, ROM index: 994, Table value: 262007, Output: -0.1337890625
# Input data: -7712, Signed input: -7.53125, float val: -7.53125, Scaled index: -30, ROM index: 994, Table value: 262007, Output: -0.1337890625
# Input data: -7680, Signed input: -7.5, float val: -7.5, Scaled index: -30, ROM index: 994, Table value: 262007, Output: -0.1337890625
# Input data: -7648, Signed input: -7.46875, float val: -7.46875, Scaled index: -29, ROM index: 995, Table value: 262003, Output: -0.1376953125
# Input data: -7616, Signed input: -7.4375, float val: -7.4375, Scaled index: -29, ROM index: 995, Table value: 262003, Output: -0.1376953125
# Input data: -7584, Signed input: -7.40625, float val: -7.40625, Scaled index: -29, ROM index: 995, Table value: 262003, Output: -0.1376953125
# Input data: -7552, Signed input: -7.375, float val: -7.375, Scaled index: -29, ROM index: 995, Table value: 262003, Output: -0.1376953125
# Input data: -7520, Signed input: -7.34375, float val: -7.34375, Scaled index: -29, ROM index: 995, Table value: 262003, Output: -0.1376953125
# Input data: -7488, Signed input: -7.3125, float val: -7.3125, Scaled index: -29, ROM index: 995, Table value: 262003, Output: -0.1376953125
# Input data: -7456, Signed input: -7.28125, float val: -7.28125, Scaled index: -29, ROM index: 995, Table value: 262003, Output: -0.1376953125
# Input data: -7424, Signed input: -7.25, float val: -7.25, Scaled index: -29, ROM index: 995, Table value: 262003, Output: -0.1376953125
# Input data: -7392, Signed input: -7.21875, float val: -7.21875, Scaled index: -28, ROM index: 996, Table value: 261998, Output: -0.142578125
# Input data: -7360, Signed input: -7.1875, float val: -7.1875, Scaled index: -28, ROM index: 996, Table value: 261998, Output: -0.142578125
# Input data: -7328, Signed input: -7.15625, float val: -7.15625, Scaled index: -28, ROM index: 996, Table value: 261998, Output: -0.142578125
# Input data: -7296, Signed input: -7.125, float val: -7.125, Scaled index: -28, ROM index: 996, Table value: 261998, Output: -0.142578125
# Input data: -7264, Signed input: -7.09375, float val: -7.09375, Scaled index: -28, ROM index: 996, Table value: 261998, Output: -0.142578125
# Input data: -7232, Signed input: -7.0625, float val: -7.0625, Scaled index: -28, ROM index: 996, Table value: 261998, Output: -0.142578125
# Input data: -7200, Signed input: -7.03125, float val: -7.03125, Scaled index: -28, ROM index: 996, Table value: 261998, Output: -0.142578125
# Input data: -7168, Signed input: -7.0, float val: -7.0, Scaled index: -28, ROM index: 996, Table value: 261998, Output: -0.142578125
# Input data: -7136, Signed input: -6.96875, float val: -6.96875, Scaled index: -27, ROM index: 997, Table value: 261992, Output: -0.1484375
# Input data: -7104, Signed input: -6.9375, float val: -6.9375, Scaled index: -27, ROM index: 997, Table value: 261992, Output: -0.1484375
# Input data: -7072, Signed input: -6.90625, float val: -6.90625, Scaled index: -27, ROM index: 997, Table value: 261992, Output: -0.1484375
# Input data: -7040, Signed input: -6.875, float val: -6.875, Scaled index: -27, ROM index: 997, Table value: 261992, Output: -0.1484375
# Input data: -7008, Signed input: -6.84375, float val: -6.84375, Scaled index: -27, ROM index: 997, Table value: 261992, Output: -0.1484375
# Input data: -6976, Signed input: -6.8125, float val: -6.8125, Scaled index: -27, ROM index: 997, Table value: 261992, Output: -0.1484375
# Input data: -6944, Signed input: -6.78125, float val: -6.78125, Scaled index: -27, ROM index: 997, Table value: 261992, Output: -0.1484375
# Input data: -6912, Signed input: -6.75, float val: -6.75, Scaled index: -27, ROM index: 997, Table value: 261992, Output: -0.1484375
# Input data: -6880, Signed input: -6.71875, float val: -6.71875, Scaled index: -26, ROM index: 998, Table value: 261986, Output: -0.154296875
# Input data: -6848, Signed input: -6.6875, float val: -6.6875, Scaled index: -26, ROM index: 998, Table value: 261986, Output: -0.154296875
# Input data: -6816, Signed input: -6.65625, float val: -6.65625, Scaled index: -26, ROM index: 998, Table value: 261986, Output: -0.154296875
# Input data: -6784, Signed input: -6.625, float val: -6.625, Scaled index: -26, ROM index: 998, Table value: 261986, Output: -0.154296875
# Input data: -6752, Signed input: -6.59375, float val: -6.59375, Scaled index: -26, ROM index: 998, Table value: 261986, Output: -0.154296875
# Input data: -6720, Signed input: -6.5625, float val: -6.5625, Scaled index: -26, ROM index: 998, Table value: 261986, Output: -0.154296875
# Input data: -6688, Signed input: -6.53125, float val: -6.53125, Scaled index: -26, ROM index: 998, Table value: 261986, Output: -0.154296875
# Input data: -6656, Signed input: -6.5, float val: -6.5, Scaled index: -26, ROM index: 998, Table value: 261986, Output: -0.154296875
# Input data: -6624, Signed input: -6.46875, float val: -6.46875, Scaled index: -25, ROM index: 999, Table value: 261980, Output: -0.16015625
# Input data: -6592, Signed input: -6.4375, float val: -6.4375, Scaled index: -25, ROM index: 999, Table value: 261980, Output: -0.16015625
# Input data: -6560, Signed input: -6.40625, float val: -6.40625, Scaled index: -25, ROM index: 999, Table value: 261980, Output: -0.16015625
# Input data: -6528, Signed input: -6.375, float val: -6.375, Scaled index: -25, ROM index: 999, Table value: 261980, Output: -0.16015625
# Input data: -6496, Signed input: -6.34375, float val: -6.34375, Scaled index: -25, ROM index: 999, Table value: 261980, Output: -0.16015625
# Input data: -6464, Signed input: -6.3125, float val: -6.3125, Scaled index: -25, ROM index: 999, Table value: 261980, Output: -0.16015625
# Input data: -6432, Signed input: -6.28125, float val: -6.28125, Scaled index: -25, ROM index: 999, Table value: 261980, Output: -0.16015625
# Input data: -6400, Signed input: -6.25, float val: -6.25, Scaled index: -25, ROM index: 999, Table value: 261980, Output: -0.16015625
# Input data: -6368, Signed input: -6.21875, float val: -6.21875, Scaled index: -24, ROM index: 1000, Table value: 261973, Output: -0.1669921875
# Input data: -6336, Signed input: -6.1875, float val: -6.1875, Scaled index: -24, ROM index: 1000, Table value: 261973, Output: -0.1669921875
# Input data: -6304, Signed input: -6.15625, float val: -6.15625, Scaled index: -24, ROM index: 1000, Table value: 261973, Output: -0.1669921875
# Input data: -6272, Signed input: -6.125, float val: -6.125, Scaled index: -24, ROM index: 1000, Table value: 261973, Output: -0.1669921875
# Input data: -6240, Signed input: -6.09375, float val: -6.09375, Scaled index: -24, ROM index: 1000, Table value: 261973, Output: -0.1669921875
# Input data: -6208, Signed input: -6.0625, float val: -6.0625, Scaled index: -24, ROM index: 1000, Table value: 261973, Output: -0.1669921875
# Input data: -6176, Signed input: -6.03125, float val: -6.03125, Scaled index: -24, ROM index: 1000, Table value: 261973, Output: -0.1669921875
# Input data: -6144, Signed input: -6.0, float val: -6.0, Scaled index: -24, ROM index: 1000, Table value: 261973, Output: -0.1669921875
# Input data: -6112, Signed input: -5.96875, float val: -5.96875, Scaled index: -23, ROM index: 1001, Table value: 261966, Output: -0.173828125
# Input data: -6080, Signed input: -5.9375, float val: -5.9375, Scaled index: -23, ROM index: 1001, Table value: 261966, Output: -0.173828125
# Input data: -6048, Signed input: -5.90625, float val: -5.90625, Scaled index: -23, ROM index: 1001, Table value: 261966, Output: -0.173828125
# Input data: -6016, Signed input: -5.875, float val: -5.875, Scaled index: -23, ROM index: 1001, Table value: 261966, Output: -0.173828125
# Input data: -5984, Signed input: -5.84375, float val: -5.84375, Scaled index: -23, ROM index: 1001, Table value: 261966, Output: -0.173828125
# Input data: -5952, Signed input: -5.8125, float val: -5.8125, Scaled index: -23, ROM index: 1001, Table value: 261966, Output: -0.173828125
# Input data: -5920, Signed input: -5.78125, float val: -5.78125, Scaled index: -23, ROM index: 1001, Table value: 261966, Output: -0.173828125
# Input data: -5888, Signed input: -5.75, float val: -5.75, Scaled index: -23, ROM index: 1001, Table value: 261966, Output: -0.173828125
# Input data: -5856, Signed input: -5.71875, float val: -5.71875, Scaled index: -22, ROM index: 1002, Table value: 261958, Output: -0.181640625
# Input data: -5824, Signed input: -5.6875, float val: -5.6875, Scaled index: -22, ROM index: 1002, Table value: 261958, Output: -0.181640625
# Input data: -5792, Signed input: -5.65625, float val: -5.65625, Scaled index: -22, ROM index: 1002, Table value: 261958, Output: -0.181640625
# Input data: -5760, Signed input: -5.625, float val: -5.625, Scaled index: -22, ROM index: 1002, Table value: 261958, Output: -0.181640625
# Input data: -5728, Signed input: -5.59375, float val: -5.59375, Scaled index: -22, ROM index: 1002, Table value: 261958, Output: -0.181640625
# Input data: -5696, Signed input: -5.5625, float val: -5.5625, Scaled index: -22, ROM index: 1002, Table value: 261958, Output: -0.181640625
# Input data: -5664, Signed input: -5.53125, float val: -5.53125, Scaled index: -22, ROM index: 1002, Table value: 261958, Output: -0.181640625
# Input data: -5632, Signed input: -5.5, float val: -5.5, Scaled index: -22, ROM index: 1002, Table value: 261958, Output: -0.181640625
# Input data: -5600, Signed input: -5.46875, float val: -5.46875, Scaled index: -21, ROM index: 1003, Table value: 261949, Output: -0.1904296875
# Input data: -5568, Signed input: -5.4375, float val: -5.4375, Scaled index: -21, ROM index: 1003, Table value: 261949, Output: -0.1904296875
# Input data: -5536, Signed input: -5.40625, float val: -5.40625, Scaled index: -21, ROM index: 1003, Table value: 261949, Output: -0.1904296875
# ...
# Input data: 12672, Signed input: 12.375, float val: 12.375, Scaled index: 49, ROM index: 49, Table value: 84, Output: 0.08203125
# Input data: 12704, Signed input: 12.40625, float val: 12.40625, Scaled index: 49, ROM index: 49, Table value: 84, Output: 0.08203125
# Input data: 12736, Signed input: 12.4375, float val: 12.4375, Scaled index: 49, ROM index: 49, Table value: 84, Output: 0.08203125
# Input data: 12768, Signed input: 12.46875, float val: 12.46875, Scaled index: 49, ROM index: 49, Table value: 84, Output: 0.08203125
# Input data: 12800, Signed input: 12.5, float val: 12.5, Scaled index: 50, ROM index: 50, Table value: 82, Output: 0.080078125
# Input data: 12832, Signed input: 12.53125, float val: 12.53125, Scaled index: 50, ROM index: 50, Table value: 82, Output: 0.080078125
# Input data: 12864, Signed input: 12.5625, float val: 12.5625, Scaled index: 50, ROM index: 50, Table value: 82, Output: 0.080078125
# Input data: 12896, Signed input: 12.59375, float val: 12.59375, Scaled index: 50, ROM index: 50, Table value: 82, Output: 0.080078125
# Input data: 12928, Signed input: 12.625, float val: 12.625, Scaled index: 50, ROM index: 50, Table value: 82, Output: 0.080078125
# Input data: 12960, Signed input: 12.65625, float val: 12.65625, Scaled index: 50, ROM index: 50, Table value: 82, Output: 0.080078125
# Input data: 12992, Signed input: 12.6875, float val: 12.6875, Scaled index: 50, ROM index: 50, Table value: 82, Output: 0.080078125
# Input data: 13024, Signed input: 12.71875, float val: 12.71875, Scaled index: 50, ROM index: 50, Table value: 82, Output: 0.080078125
# Input data: 13056, Signed input: 12.75, float val: 12.75, Scaled index: 51, ROM index: 51, Table value: 80, Output: 0.078125
# Input data: 13088, Signed input: 12.78125, float val: 12.78125, Scaled index: 51, ROM index: 51, Table value: 80, Output: 0.078125
# Input data: 13120, Signed input: 12.8125, float val: 12.8125, Scaled index: 51, ROM index: 51, Table value: 80, Output: 0.078125
# Input data: 13152, Signed input: 12.84375, float val: 12.84375, Scaled index: 51, ROM index: 51, Table value: 80, Output: 0.078125
# Input data: 13184, Signed input: 12.875, float val: 12.875, Scaled index: 51, ROM index: 51, Table value: 80, Output: 0.078125
# Input data: 13216, Signed input: 12.90625, float val: 12.90625, Scaled index: 51, ROM index: 51, Table value: 80, Output: 0.078125
# Input data: 13248, Signed input: 12.9375, float val: 12.9375, Scaled index: 51, ROM index: 51, Table value: 80, Output: 0.078125
# Input data: 13280, Signed input: 12.96875, float val: 12.96875, Scaled index: 51, ROM index: 51, Table value: 80, Output: 0.078125
# Input data: 13312, Signed input: 13.0, float val: 13.0, Scaled index: 52, ROM index: 52, Table value: 79, Output: 0.0771484375
# Input data: 13344, Signed input: 13.03125, float val: 13.03125, Scaled index: 52, ROM index: 52, Table value: 79, Output: 0.0771484375
# Input data: 13376, Signed input: 13.0625, float val: 13.0625, Scaled index: 52, ROM index: 52, Table value: 79, Output: 0.0771484375
# Input data: 13408, Signed input: 13.09375, float val: 13.09375, Scaled index: 52, ROM index: 52, Table value: 79, Output: 0.0771484375
# Input data: 13440, Signed input: 13.125, float val: 13.125, Scaled index: 52, ROM index: 52, Table value: 79, Output: 0.0771484375
# Input data: 13472, Signed input: 13.15625, float val: 13.15625, Scaled index: 52, ROM index: 52, Table value: 79, Output: 0.0771484375
# Input data: 13504, Signed input: 13.1875, float val: 13.1875, Scaled index: 52, ROM index: 52, Table value: 79, Output: 0.0771484375
# Input data: 13536, Signed input: 13.21875, float val: 13.21875, Scaled index: 52, ROM index: 52, Table value: 79, Output: 0.0771484375
# Input data: 13568, Signed input: 13.25, float val: 13.25, Scaled index: 53, ROM index: 53, Table value: 77, Output: 0.0751953125
# Input data: 13600, Signed input: 13.28125, float val: 13.28125, Scaled index: 53, ROM index: 53, Table value: 77, Output: 0.0751953125
# Input data: 13632, Signed input: 13.3125, float val: 13.3125, Scaled index: 53, ROM index: 53, Table value: 77, Output: 0.0751953125
# Input data: 13664, Signed input: 13.34375, float val: 13.34375, Scaled index: 53, ROM index: 53, Table value: 77, Output: 0.0751953125
# Input data: 13696, Signed input: 13.375, float val: 13.375, Scaled index: 53, ROM index: 53, Table value: 77, Output: 0.0751953125
# Input data: 13728, Signed input: 13.40625, float val: 13.40625, Scaled index: 53, ROM index: 53, Table value: 77, Output: 0.0751953125
# Input data: 13760, Signed input: 13.4375, float val: 13.4375, Scaled index: 53, ROM index: 53, Table value: 77, Output: 0.0751953125
# Input data: 13792, Signed input: 13.46875, float val: 13.46875, Scaled index: 53, ROM index: 53, Table value: 77, Output: 0.0751953125
# Input data: 13824, Signed input: 13.5, float val: 13.5, Scaled index: 54, ROM index: 54, Table value: 76, Output: 0.07421875
# Input data: 13856, Signed input: 13.53125, float val: 13.53125, Scaled index: 54, ROM index: 54, Table value: 76, Output: 0.07421875
# Input data: 13888, Signed input: 13.5625, float val: 13.5625, Scaled index: 54, ROM index: 54, Table value: 76, Output: 0.07421875
# Input data: 13920, Signed input: 13.59375, float val: 13.59375, Scaled index: 54, ROM index: 54, Table value: 76, Output: 0.07421875
# Input data: 13952, Signed input: 13.625, float val: 13.625, Scaled index: 54, ROM index: 54, Table value: 76, Output: 0.07421875
# Input data: 13984, Signed input: 13.65625, float val: 13.65625, Scaled index: 54, ROM index: 54, Table value: 76, Output: 0.07421875
# Input data: 14016, Signed input: 13.6875, float val: 13.6875, Scaled index: 54, ROM index: 54, Table value: 76, Output: 0.07421875
# Input data: 14048, Signed input: 13.71875, float val: 13.71875, Scaled index: 54, ROM index: 54, Table value: 76, Output: 0.07421875
# Input data: 14080, Signed input: 13.75, float val: 13.75, Scaled index: 55, ROM index: 55, Table value: 74, Output: 0.072265625
# Input data: 14112, Signed input: 13.78125, float val: 13.78125, Scaled index: 55, ROM index: 55, Table value: 74, Output: 0.072265625
# Input data: 14144, Signed input: 13.8125, float val: 13.8125, Scaled index: 55, ROM index: 55, Table value: 74, Output: 0.072265625
# Input data: 14176, Signed input: 13.84375, float val: 13.84375, Scaled index: 55, ROM index: 55, Table value: 74, Output: 0.072265625
# Input data: 14208, Signed input: 13.875, float val: 13.875, Scaled index: 55, ROM index: 55, Table value: 74, Output: 0.072265625
# Input data: 14240, Signed input: 13.90625, float val: 13.90625, Scaled index: 55, ROM index: 55, Table value: 74, Output: 0.072265625
# Input data: 14272, Signed input: 13.9375, float val: 13.9375, Scaled index: 55, ROM index: 55, Table value: 74, Output: 0.072265625
# Input data: 14304, Signed input: 13.96875, float val: 13.96875, Scaled index: 55, ROM index: 55, Table value: 74, Output: 0.072265625
# Input data: 14336, Signed input: 14.0, float val: 14.0, Scaled index: 56, ROM index: 56, Table value: 73, Output: 0.0712890625
# Input data: 14368, Signed input: 14.03125, float val: 14.03125, Scaled index: 56, ROM index: 56, Table value: 73, Output: 0.0712890625
# Input data: 14400, Signed input: 14.0625, float val: 14.0625, Scaled index: 56, ROM index: 56, Table value: 73, Output: 0.0712890625
# Input data: 14432, Signed input: 14.09375, float val: 14.09375, Scaled index: 56, ROM index: 56, Table value: 73, Output: 0.0712890625
# Input data: 14464, Signed input: 14.125, float val: 14.125, Scaled index: 56, ROM index: 56, Table value: 73, Output: 0.0712890625
# Input data: 14496, Signed input: 14.15625, float val: 14.15625, Scaled index: 56, ROM index: 56, Table value: 73, Output: 0.0712890625
# Input data: 14528, Signed input: 14.1875, float val: 14.1875, Scaled index: 56, ROM index: 56, Table value: 73, Output: 0.0712890625
# Input data: 14560, Signed input: 14.21875, float val: 14.21875, Scaled index: 56, ROM index: 56, Table value: 73, Output: 0.0712890625
# Input data: 14592, Signed input: 14.25, float val: 14.25, Scaled index: 57, ROM index: 57, Table value: 72, Output: 0.0703125
# Input data: 14624, Signed input: 14.28125, float val: 14.28125, Scaled index: 57, ROM index: 57, Table value: 72, Output: 0.0703125
# Input data: 14656, Signed input: 14.3125, float val: 14.3125, Scaled index: 57, ROM index: 57, Table value: 72, Output: 0.0703125
# Input data: 14688, Signed input: 14.34375, float val: 14.34375, Scaled index: 57, ROM index: 57, Table value: 72, Output: 0.0703125
# Input data: 14720, Signed input: 14.375, float val: 14.375, Scaled index: 57, ROM index: 57, Table value: 72, Output: 0.0703125
# Input data: 14752, Signed input: 14.40625, float val: 14.40625, Scaled index: 57, ROM index: 57, Table value: 72, Output: 0.0703125
# Input data: 14784, Signed input: 14.4375, float val: 14.4375, Scaled index: 57, ROM index: 57, Table value: 72, Output: 0.0703125
# Input data: 14816, Signed input: 14.46875, float val: 14.46875, Scaled index: 57, ROM index: 57, Table value: 72, Output: 0.0703125
# Input data: 14848, Signed input: 14.5, float val: 14.5, Scaled index: 58, ROM index: 58, Table value: 71, Output: 0.0693359375
# Input data: 14880, Signed input: 14.53125, float val: 14.53125, Scaled index: 58, ROM index: 58, Table value: 71, Output: 0.0693359375
# Input data: 14912, Signed input: 14.5625, float val: 14.5625, Scaled index: 58, ROM index: 58, Table value: 71, Output: 0.0693359375
# Input data: 14944, Signed input: 14.59375, float val: 14.59375, Scaled index: 58, ROM index: 58, Table value: 71, Output: 0.0693359375
# Input data: 14976, Signed input: 14.625, float val: 14.625, Scaled index: 58, ROM index: 58, Table value: 71, Output: 0.0693359375
# Input data: 15008, Signed input: 14.65625, float val: 14.65625, Scaled index: 58, ROM index: 58, Table value: 71, Output: 0.0693359375
# Input data: 15040, Signed input: 14.6875, float val: 14.6875, Scaled index: 58, ROM index: 58, Table value: 71, Output: 0.0693359375
# Input data: 15072, Signed input: 14.71875, float val: 14.71875, Scaled index: 58, ROM index: 58, Table value: 71, Output: 0.0693359375
# Input data: 15104, Signed input: 14.75, float val: 14.75, Scaled index: 59, ROM index: 59, Table value: 69, Output: 0.0673828125
# Input data: 15136, Signed input: 14.78125, float val: 14.78125, Scaled index: 59, ROM index: 59, Table value: 69, Output: 0.0673828125
# Input data: 15168, Signed input: 14.8125, float val: 14.8125, Scaled index: 59, ROM index: 59, Table value: 69, Output: 0.0673828125
# Input data: 15200, Signed input: 14.84375, float val: 14.84375, Scaled index: 59, ROM index: 59, Table value: 69, Output: 0.0673828125
# Input data: 15232, Signed input: 14.875, float val: 14.875, Scaled index: 59, ROM index: 59, Table value: 69, Output: 0.0673828125
# Input data: 15264, Signed input: 14.90625, float val: 14.90625, Scaled index: 59, ROM index: 59, Table value: 69, Output: 0.0673828125
# Input data: 15296, Signed input: 14.9375, float val: 14.9375, Scaled index: 59, ROM index: 59, Table value: 69, Output: 0.0673828125
# Input data: 15328, Signed input: 14.96875, float val: 14.96875, Scaled index: 59, ROM index: 59, Table value: 69, Output: 0.0673828125
# Input data: 15360, Signed input: 15.0, float val: 15.0, Scaled index: 60, ROM index: 60, Table value: 68, Output: 0.06640625
# Input data: 15392, Signed input: 15.03125, float val: 15.03125, Scaled index: 60, ROM index: 60, Table value: 68, Output: 0.06640625
# Input data: 15424, Signed input: 15.0625, float val: 15.0625, Scaled index: 60, ROM index: 60, Table value: 68, Output: 0.06640625
# Input data: 15456, Signed input: 15.09375, float val: 15.09375, Scaled index: 60, ROM index: 60, Table value: 68, Output: 0.06640625
# Input data: 15488, Signed input: 15.125, float val: 15.125, Scaled index: 60, ROM index: 60, Table value: 68, Output: 0.06640625
# Input data: 15520, Signed input: 15.15625, float val: 15.15625, Scaled index: 60, ROM index: 60, Table value: 68, Output: 0.06640625
# Input data: 15552, Signed input: 15.1875, float val: 15.1875, Scaled index: 60, ROM index: 60, Table value: 68, Output: 0.06640625
# Input data: 15584, Signed input: 15.21875, float val: 15.21875, Scaled index: 60, ROM index: 60, Table value: 68, Output: 0.06640625
# Input data: 15616, Signed input: 15.25, float val: 15.25, Scaled index: 61, ROM index: 61, Table value: 67, Output: 0.0654296875
# Input data: 15648, Signed input: 15.28125, float val: 15.28125, Scaled index: 61, ROM index: 61, Table value: 67, Output: 0.0654296875
# Input data: 15680, Signed input: 15.3125, float val: 15.3125, Scaled index: 61, ROM index: 61, Table value: 67, Output: 0.0654296875
# Input data: 15712, Signed input: 15.34375, float val: 15.34375, Scaled index: 61, ROM index: 61, Table value: 67, Output: 0.0654296875
# Input data: 15744, Signed input: 15.375, float val: 15.375, Scaled index: 61, ROM index: 61, Table value: 67, Output: 0.0654296875
# Input data: 15776, Signed input: 15.40625, float val: 15.40625, Scaled index: 61, ROM index: 61, Table value: 67, Output: 0.0654296875
# Input data: 15808, Signed input: 15.4375, float val: 15.4375, Scaled index: 61, ROM index: 61, Table value: 67, Output: 0.0654296875
# Input data: 15840, Signed input: 15.46875, float val: 15.46875, Scaled index: 61, ROM index: 61, Table value: 67, Output: 0.0654296875
# Input data: 15872, Signed input: 15.5, float val: 15.5, Scaled index: 62, ROM index: 62, Table value: 66, Output: 0.064453125
# Input data: 15904, Signed input: 15.53125, float val: 15.53125, Scaled index: 62, ROM index: 62, Table value: 66, Output: 0.064453125
# Input data: 15936, Signed input: 15.5625, float val: 15.5625, Scaled index: 62, ROM index: 62, Table value: 66, Output: 0.064453125
# Input data: 15968, Signed input: 15.59375, float val: 15.59375, Scaled index: 62, ROM index: 62, Table value: 66, Output: 0.064453125
# Input data: 16000, Signed input: 15.625, float val: 15.625, Scaled index: 62, ROM index: 62, Table value: 66, Output: 0.064453125
# Input data: 16032, Signed input: 15.65625, float val: 15.65625, Scaled index: 62, ROM index: 62, Table value: 66, Output: 0.064453125
# Input data: 16064, Signed input: 15.6875, float val: 15.6875, Scaled index: 62, ROM index: 62, Table value: 66, Output: 0.064453125
# Input data: 16096, Signed input: 15.71875, float val: 15.71875, Scaled index: 62, ROM index: 62, Table value: 66, Output: 0.064453125
# Input data: 16128, Signed input: 15.75, float val: 15.75, Scaled index: 63, ROM index: 63, Table value: 65, Output: 0.0634765625
# Input data: 16160, Signed input: 15.78125, float val: 15.78125, Scaled index: 63, ROM index: 63, Table value: 65, Output: 0.0634765625
# Input data: 16192, Signed input: 15.8125, float val: 15.8125, Scaled index: 63, ROM index: 63, Table value: 65, Output: 0.0634765625
# Input data: 16224, Signed input: 15.84375, float val: 15.84375, Scaled index: 63, ROM index: 63, Table value: 65, Output: 0.0634765625
# Input data: 16256, Signed input: 15.875, float val: 15.875, Scaled index: 63, ROM index: 63, Table value: 65, Output: 0.0634765625
# Input data: 16288, Signed input: 15.90625, float val: 15.90625, Scaled index: 63, ROM index: 63, Table value: 65, Output: 0.0634765625
# Input data: 16320, Signed input: 15.9375, float val: 15.9375, Scaled index: 63, ROM index: 63, Table value: 65, Output: 0.0634765625
# Input data: 16352, Signed input: 15.96875, float val: 15.96875, Scaled index: 63, ROM index: 63, Table value: 65, Output: 0.0634765625
# last value 0.0634765625
# /tmp/ipykernel_20934/2660080827.py:12: RuntimeWarning: divide by zero encountered in divide
#   axs[0].plot(x_proper, 1 / (x_proper), label=r"True $1/x$", color="green", alpha=0.5)
# /tmp/ipykernel_20934/2660080827.py:24: RuntimeWarning: divide by zero encountered in divide
#   axs[1].plot(x_proper, 1 / (x_proper), label=r"True $1/x$", color="green", alpha=0.5)
# /tmp/ipykernel_20934/2660080827.py:36: RuntimeWarning: divide by zero encountered in divide
#   axs[2].plot(x_proper, 1 / (x_proper), label=r"True $1/x$", color="green", alpha=0.5)

# %%
def load_rom_from_dat(filepath: str, data_fmt="18_10", signed=False) -> list[int]:
    """Load ROM from .dat file where each line is a signed/unsigned integer."""
    with open(filepath, 'r') as f:
        lines = f.readlines()
    rom = []
    for line in lines:
        # Remove whitespace and comments
        line = line.split('//')[0].strip()
        if not line:
            continue
        # Convert to integer
        val = int(line, 16)
        # Convert to signed fixed-point if needed
        if signed:
            if val & (1 << (int(data_fmt.split('_')[0]) - 1)):
                val -= (1 << int(data_fmt.split('_')[0]))
        rom.append(val)
    return rom

# def lookup(input_val: int, rom: list[int], shift_amount=6) -> float:
#     """
#     input_val: signed 16_10 fixed-point integer
#     rom: list of 1024 signed 18_10 fixed-point values
#     """
#     # Step 1: Shift to convert 16_10 -> 10_4 signed fixed-point
#     signed_addr = input_val >> shift_amount

#     # Step 2: Reinterpret signed 10-bit as unsigned index
#     rom_index = signed_addr & 0x3FF

#     # Step 3: Lookup in ROM and convert to float
#     rom_val = rom[rom_index]
#     return signed_fixed_to_float(rom_val, nfrac=10, nbits=18)
def lookup(input_val: int, rom: list[int], input_data_fmt="16_10", address_fmt="10_4", table_data_fmt="18_10", table_data_signed=False, debug=False) -> float:
    """
    Simulates a fixed-point lookup table read (like for exp or reciprocal ROMs).

    Parameters:
    - input_val: Fixed-point integer input to look up.
    - rom: List of ROM values (integers).
    - input_data_fmt: Format of input fixed-point number as "total_frac", e.g. "16_10" means 16 total bits, 10 fractional.
    - address_fmt: Format of the ROM address as "total_frac", e.g. "10_4" means 10-bit address, with 4 fractional bits.
    - table_data_signed: Whether the data in ROM is signed.
    - debug: If True, print intermediate info.

    Returns:
    - float: The floating-point representation of the looked-up value.
    """
    import math

    # Parse formats
    in_total, in_frac = map(int, input_data_fmt.split('_'))
    addr_total, addr_frac = map(int, address_fmt.split('_'))
    table_total, table_frac = map(int, table_data_fmt.split('_'))
    

    # # Convert input_val to address by shifting right to discard LSBs
    addr = (input_val >> (in_frac - addr_frac)) & ((1 << addr_total) - 1)
    
    # addr = input_val >> (in_frac - addr_frac)

    if addr >= len(rom):
        raise IndexError(f"Address {addr} out of ROM bounds (ROM size: {len(rom)})")

    rom_val = rom[addr]
    
    # Convert ROM value to signed fixed-point
    # If the ROM value is negative, we need to convert it to signed fixed-point
    # by subtracting 2^table_total
    if table_data_signed:
        if rom_val & (1 << (table_total - 1)):
            rom_val -= (1 << table_total)
    else:
        # If the ROM value is unsigned, we need to reinterpret it as signed
        # by masking with (1 << table_total) - 1
        rom_val &= (1 << table_total) - 1
    # Convert ROM value to float

    # # Interpret as signed if needed
    if table_data_signed:
        rom_val = rom_val - (1 << (addr_total)) if rom_val & (1 << (addr_total - 1)) else rom_val

    # Convert ROM output to float assuming full scale is 1 << addr_frac
    result = rom_val / (2.0 ** table_frac)

    if debug:
        print(f"[DEBUG] input_val: {input_val}")
        print(f"[DEBUG] input_val (binary): {input_val:0{in_total}b}")
        print(f"[DEBUG] addr: {addr}")
        print(f"[DEBUG] addr (binary): {addr:0{addr_total}b}")
        print(f"[DEBUG] rom_val (raw): {rom[addr]}")
        # print(f"[DEBUG] rom_val (signed): {rom_val}")
        print(f"[DEBUG] result: {result}")

    return result


filepath = "/home/donovan/code/research/hls4ml/waiz-khan-files/model_7/16_10_prj/myproject_prj/solution1/impl/verilog/softmax_stable_ap_fixed_ap_fixed_16_10_5_3_0_softmax_config16_s_exp_table1_rom.dat"

rom = load_rom_from_dat(filepath)

# Example input value
for input_val in [
    # 0b00_10000_00000,
    # 0b00_01000_00001,
    # 0b00_00010_00001,
    0xFF59,
    ]:
    # Perform lookup directly with the integer input value
    output_val = lookup(input_val, rom, address_fmt="10_4", table_data_fmt="18_10", table_data_signed=False, debug=True)
    print(f"Input value (fixed-point): {fixed_to_float(input_val, nfrac=10, nbits=16, signed=True)}")
    print(f"Output value (float): {output_val}")
    print()



# Now plot this for all possible values representable by signed 16_10
# also include the real exp function for comparison
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-32768, 32768)  # Adjusted range to include all representable values
y = np.array([lookup(val, rom, address_fmt="10_0", table_data_fmt="18_10", table_data_signed=False) for val in x])

# Convert fixed-point x values to float for comparison
x_float = x / (1 << 10)
y_true = np.exp(x_float)  # True exponential values

x_0_to_50 = np.arange(0, 50)

plt.figure(figsize=(6, 3))
plt.plot(x_float, y, label=r"RTL $e^x$ approximation", color="orange", marker=".")
plt.plot(x_float, y_true, label=r"True $e^x$", color="green")
# plt.plot(x_0_to_50, np.exp(x_0_to_50), 'o--', label="True exp (0 to 50)")

# add a point for x=4
# plt.plot(4, np.exp(4), 'go', label="True exp at x=4")
plt.legend()
plt.title("RTL Exponential vs True Exponential")
plt.xlabel("Input value (float)")
plt.ylabel("Output value (float)")
# plt.xlim(-2.5, 5)
plt.ylim(-10, 130)
plt.grid()
plt.savefig("scripts/output/rtl_exp_vs_true_exp.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# [DEBUG] input_val: 65369
# [DEBUG] input_val (binary): 1111111101011001
# [DEBUG] addr: 1021
# [DEBUG] addr (binary): 1111111101
# [DEBUG] rom_val (raw): 51
# [DEBUG] result: 0.0498046875
# HELLO
# Input value (fixed-point): -0.1630859375
# Output value (float): 0.0498046875

# %%
fixed = "045C"
output = "40031"
print(f"Fixed point value in float: {signed_fixed_to_float(int(fixed, 16), nfrac=10, nbits=16)}")
# exponentiate using table
print(f"Exponentiated value using table: {lookup(int("10", 16), rom)}")
print(f"model sim output: {signed_fixed_to_float(int(output, 16), nfrac=10, nbits=18)}")
# Out:
#   Cell In[80], line 5
#     print(f"Exponentiated value using table: {lookup(int("10", 16), rom)}")
#                                                           ^
# SyntaxError: f-string: unmatched '('

# %%
number = 127.9990234375 * 2 + 0.0498046875
print(f"Number: {number}")
# Out:
# Number: 256.0478515625

# %%
temp_sum = "40031"
temp_sum = signed_fixed_to_float(int(temp_sum, 16), nfrac=10, nbits=18)
print(f"temp_sum: {temp_sum}")
exp_sum = "14"

exp_sum = signed_fixed_to_float(int(exp_sum, 16), nfrac=2, nbits=10)
print(f"exp_sum: {exp_sum}")
# Out:
# temp_sum: 256.0478515625
# exp_sum: 5.0

# %%
sixteen_bit_fixed = "08"
print(f"16-bit fixed point value: {signed_fixed_to_float(int(sixteen_bit_fixed, 16), nfrac=10, nbits=18)}")
# Out:
# 16-bit fixed point value: 0.0078125

# %%
print(127.9990234375 * 0.0078125)
# Out:
# 0.9999923706054688

# %% [markdown]
# ## Invert Table

# %%
inv_filepath = '/home/donovan/code/research/hls4ml/waiz-khan-files/model_7/16_10_prj/myproject_prj/solution1/impl/verilog/softmax_stable_ap_fixed_ap_fixed_16_10_5_3_0_softmax_config16_s_invert_table2_rom.dat'
inv_rom = load_rom_from_dat(inv_filepath)
# Example input value

invert_index = "1ff"
invert_index = int(invert_index, 16)
print(f"Lookup index: {invert_index}")
invert = lookup(invert_index, inv_rom, shift_amount=0)
print(f"Lookup value: {invert}")
# Out:
# Lookup index: 511
# Lookup value: 0.12890625

# %%
lookup(2 << 10, inv_rom, shift_amount=8)
# Out:
# 127.9990234375

# %%
# x = np.arange(-32768, 32768)  # Adjusted range to include all representable values
y_inv = np.array([lookup(val, inv_rom, shift_amount=8) for val in x])

# Convert fixed-point x values to float for comparison
x_float = x / (1 << 10)
y_true = 1 / x_float  # True inverse values

plt.plot(x_float, y_inv, label="Inverse lookup", color="blue", marker=".")
plt.plot(x_float, y_true, label="True inverse", color="red")
plt.legend()
plt.title("Inverse lookup table vs True inverse")
plt.xlabel("Input value (float)")
plt.ylabel("Output value (float)")
plt.ylim(-10, 200)
plt.xlim(-10, 4)
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_12459/2584941588.py:6: RuntimeWarning: divide by zero encountered in divide
#   y_true = 1 / x_float  # True inverse values

# %%
number = "FF59"
print(f"16-bit fixed point value: {signed_fixed_to_float(int(number, 16), nfrac=10, nbits=16)}")
# Out:
# 16-bit fixed point value: -0.1630859375
