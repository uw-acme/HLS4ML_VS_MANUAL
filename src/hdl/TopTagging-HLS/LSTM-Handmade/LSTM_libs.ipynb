# %%
import sys
from pathlib import Path
import os
currentdir = os.getcwd()
ind = currentdir.find("HLS4ML_VS_MANUAL")
root_folder = currentdir[0:ind+len("HLS4ML_VS_MANUAL")]
path = os.path.join(root_folder, "src/hdl/Batchnorm-JetTagging")
sys.path.insert(1,path)
import helper_functions as f
from tensorflow.keras.models import load_model
# Out:
# 2026-02-22 19:58:49.534798: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-22 19:58:49.645006: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-22 19:58:49.645031: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-22 19:58:49.663258: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-02-22 19:58:49.700693: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
import importlib
importlib.reload(f)
# Out:
# <module 'helper_functions' from '/home/caleb/ACME/HLS4ML_VS_MANUAL/src/hdl/Batchnorm-JetTagging/helper_functions.py'>

# %%
model=load_model("../model_toptag_lstm.h5")
# for layer in model.layers:
#     print("amount of weights", len(layer.get_weights()))
#     for thing in layer.get_weights():
#         print("Length1 of weight array",len(thing))
#         try:
#             print("Length2 of weight array", len(thing[0]))
#         except:
#             pass
    # print(len(layer.get_weights()))
    # print(len(layer.get_weights()[0]))
f.gen_weight((16,6), model, "")
# Out:
# 2 1
