# %%
import sys
sys.path.insert(1,"/home/caleb/HLS4ML_VS_MANUAL/src/hdl/Batchnorm-JetTagging/")
import helper_functions as f
from tensorflow.keras.models import load_model

# %%
import importlib
importlib.reload(f)
# Out:
# <module 'helper_functions' from '/home/caleb/HLS4ML_VS_MANUAL/src/hdl/Batchnorm-JetTagging/helper_functions.py'>

# %%
model=load_model("../model_toptag_lstm.h5")
# for layer in model.layers:
#     print("amount of weights", len(layer.get_weights()))
#     for thing in layer.get_weights():
#         print("Length1 of weight array",len(thing))
#         try:
#             print("Length2 of weight array", len(thing[0]))
#         except:
#             pass
    # print(len(layer.get_weights()))
    # print(len(layer.get_weights()[0]))
f.gen_weight((16,6), model, "")
# Out:
# amount of weights 3
# Length1 of weight array 6
# Length2 of weight array 80
# Length1 of weight array 20
# Length2 of weight array 80
# Length1 of weight array 80
# amount of weights 2
# Length1 of weight array 20
# Length2 of weight array 64
# Length1 of weight array 64
# amount of weights 2
# Length1 of weight array 64
# Length2 of weight array 1
# Length1 of weight array 1
