# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import matplotlib.pyplot as plt

# Load model
model = load_model('./lstm/Quickdraw5Class1.h5')
model_edit = load_model('./lstm/Quickdraw5Class1_edit.h5')
model_8020 = load_model('./lstm/Quickdraw5Class1_8020.h5')
model_edit_8020 = load_model('./lstm/Quickdraw5Class1_edit_8020.h5')

# Load test data
X_test = np.load('X_test.npy', allow_pickle=True)
y_test = np.load('y_test.npy', allow_pickle=True)
# X_test = np.load('X_train.npy', allow_pickle=True)
# y_test = np.load('y_train.npy', allow_pickle=True)

# %%
X_testzero = np.zeros((len(X_test), 100, 3))

for x in range(len(X_test)):
    for y in range(100):
        for z in range(3):
            if y >= len(X_test[x]):
                break
            X_testzero[x][y][z] = X_test[x][y][z]

# %%
# encode labels for 5 classes
num_classes = 5
y_labhot = np.zeros((len(y_test),5))

y_labhot.shape

num = 0
for x in y_test:
  if x == 0:
    y_labhot[num][0] = 1
  elif x == 1: 
    y_labhot[num][1] = 1
  elif x == 2: 
    y_labhot[num][2] = 1
  elif x == 3: 
    y_labhot[num][3] = 1
  elif x == 4: 
    y_labhot[num][4] = 1
  num = num + 1

# %%
loss, acc = model.evaluate(X_testzero, y_labhot, batch_size=512, verbose=1)
print(f"LSTM Test Loss: {loss:.4f}")
print(f"LSTM Test Accuracy: {acc:.4f}")
# Out:
# 25/25 [==============================] - 4s 127ms/step - loss: 0.2251 - accuracy: 0.9237
# LSTM Test Loss: 0.2251
# LSTM Test Accuracy: 0.9237

# %%
y_pred_probs = model.predict(X_testzero, batch_size=512)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_labhot, axis=1)

from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_true, y_pred, target_names=['ant', 'bee', 'butterfly', 'mosquito', 'snail']))
# Out:
# 25/25 [==============================] - 4s 125ms/step
#               precision    recall  f1-score   support
#
#          ant       0.92      0.93      0.92      2500
#          bee       0.91      0.92      0.92      2500
#    butterfly       0.96      0.97      0.96      2500
#     mosquito       0.87      0.82      0.85      2500
#        snail       0.96      0.97      0.97      2500
#
#     accuracy                           0.92     12500
#    macro avg       0.92      0.92      0.92     12500
# weighted avg       0.92      0.92      0.92     12500

# %%
loss, acc = model_edit.evaluate(X_testzero, y_labhot, batch_size=512, verbose=1)
print(f"LSTM Test Loss: {loss:.4f}")
print(f"LSTM Test Accuracy: {acc:.4f}")
# Out:
# 25/25 [==============================] - 4s 127ms/step - loss: 0.1762 - accuracy: 0.9492
# LSTM Test Loss: 0.1762
# LSTM Test Accuracy: 0.9492

# %%
y_pred_probs = model_edit.predict(X_testzero, batch_size=512)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_labhot, axis=1)

from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_true, y_pred, target_names=['ant', 'bee', 'butterfly', 'mosquito', 'snail']))
# Out:
# 25/25 [==============================] - 4s 127ms/step
#               precision    recall  f1-score   support
#
#          ant       0.94      0.96      0.95      2500
#          bee       0.94      0.95      0.94      2500
#    butterfly       0.97      0.97      0.97      2500
#     mosquito       0.91      0.87      0.89      2500
#        snail       0.98      0.99      0.99      2500
#
#     accuracy                           0.95     12500
#    macro avg       0.95      0.95      0.95     12500
# weighted avg       0.95      0.95      0.95     12500

# %%
loss, acc = model_8020.evaluate(X_testzero, y_labhot, batch_size=512, verbose=1)
print(f"LSTM Test Loss: {loss:.4f}")
print(f"LSTM Test Accuracy: {acc:.4f}")
# Out:
# 25/25 [==============================] - 4s 125ms/step - loss: 0.2377 - accuracy: 0.9185
# LSTM Test Loss: 0.2377
# LSTM Test Accuracy: 0.9185

# %%
y_pred_probs = model_8020.predict(X_testzero, batch_size=512)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_labhot, axis=1)

from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_true, y_pred, target_names=['ant', 'bee', 'butterfly', 'mosquito', 'snail']))
# Out:
# 25/25 [==============================] - 4s 125ms/step
#               precision    recall  f1-score   support
#
#          ant       0.91      0.93      0.92      2500
#          bee       0.89      0.93      0.91      2500
#    butterfly       0.96      0.96      0.96      2500
#     mosquito       0.87      0.80      0.83      2500
#        snail       0.96      0.97      0.97      2500
#
#     accuracy                           0.92     12500
#    macro avg       0.92      0.92      0.92     12500
# weighted avg       0.92      0.92      0.92     12500

# %%
loss, acc = model_edit_8020.evaluate(X_testzero, y_labhot, batch_size=512, verbose=1)
print(f"LSTM Test Loss: {loss:.4f}")
print(f"LSTM Test Accuracy: {acc:.4f}")
# Out:
# 25/25 [==============================] - 4s 127ms/step - loss: 0.1631 - accuracy: 0.9502
# LSTM Test Loss: 0.1631
# LSTM Test Accuracy: 0.9502

# %%
y_pred_probs = model_edit_8020.predict(X_testzero, batch_size=512)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_labhot, axis=1)

from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_true, y_pred, target_names=['ant', 'bee', 'butterfly', 'mosquito', 'snail']))
# Out:
# 25/25 [==============================] - 4s 126ms/step
#               precision    recall  f1-score   support
#
#          ant       0.95      0.95      0.95      2500
#          bee       0.93      0.95      0.94      2500
#    butterfly       0.97      0.98      0.98      2500
#     mosquito       0.90      0.89      0.89      2500
#        snail       0.99      0.99      0.99      2500
#
#     accuracy                           0.95     12500
#    macro avg       0.95      0.95      0.95     12500
# weighted avg       0.95      0.95      0.95     12500
