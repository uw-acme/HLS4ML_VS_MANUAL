# %%
import json
import pandas as pd
import h5py
import numpy as np
import tensorflow as tf
import keras
from tensorflow.keras.layers import Dense, GRU
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

gru = load_model('./Quickdraw-JY/Quickdraw5Class1GRU.h5')
lstm = load_model('./Quickdraw-JY/Quickdraw5ClassLSTMFinL.h5')
# Out:
# 2026-02-08 16:54:20.110479: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-08 16:54:20.151712: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-08 16:54:20.151755: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-08 16:54:20.152973: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-02-08 16:54:20.159341: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-08 16:54:20.160180: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-08 16:54:21.197737: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
plot_model(gru, show_shapes=True, show_layer_names=True)

# %%
plot_model(lstm, show_shapes=True, show_layer_names=True)
