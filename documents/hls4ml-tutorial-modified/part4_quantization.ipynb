# %% [markdown]
# # Part 4: Quantization

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
seed = 0
np.random.seed(seed)
import tensorflow as tf

tf.random.set_seed(seed)
import os

# %% [markdown]
# ## Fetch the jet tagging dataset from Open ML

# %%
X_train_val = np.load('X_train_val.npy')
X_test = np.load('X_test.npy')
y_train_val = np.load('y_train_val.npy')
y_test = np.load('y_test.npy')
classes = np.load('classes.npy', allow_pickle=True)

# %% [markdown]
# ## Construct a model
# This time we're going to use QKeras layers.
# QKeras is "Quantized Keras" for deep heterogeneous quantization of ML models.
#
# https://github.com/google/qkeras
#
# It is maintained by Google and we recently added support for QKeras model to hls4ml.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1
from callbacks import all_callbacks
from tensorflow.keras.layers import Activation
from qkeras.qlayers import QDense, QActivation
from qkeras.quantizers import quantized_bits, quantized_relu

# %% [markdown]
# We're using `QDense` layer instead of `Dense`, and `QActivation` instead of `Activation`. We're also specifying `kernel_quantizer = quantized_bits(6,0,0)`. This will use 6-bits (of which 0 are integer) for the weights. We also use the same quantization for the biases, and `quantized_relu(6)` for 6-bit ReLU activations.

# %%
model = Sequential()
model.add(
    QDense(
        64,
        input_shape=(16,),
        name='fc1',
        kernel_quantizer=quantized_bits(6, 0, alpha=1),
        bias_quantizer=quantized_bits(6, 0, alpha=1),
        kernel_initializer='lecun_uniform',
        kernel_regularizer=l1(0.0001),
    )
)
model.add(QActivation(activation=quantized_relu(6), name='relu1'))
model.add(
    QDense(
        32,
        name='fc2',
        kernel_quantizer=quantized_bits(6, 0, alpha=1),
        bias_quantizer=quantized_bits(6, 0, alpha=1),
        kernel_initializer='lecun_uniform',
        kernel_regularizer=l1(0.0001),
    )
)
model.add(QActivation(activation=quantized_relu(6), name='relu2'))
model.add(
    QDense(
        32,
        name='fc3',
        kernel_quantizer=quantized_bits(6, 0, alpha=1),
        bias_quantizer=quantized_bits(6, 0, alpha=1),
        kernel_initializer='lecun_uniform',
        kernel_regularizer=l1(0.0001),
    )
)
model.add(QActivation(activation=quantized_relu(6), name='relu3'))
model.add(
    QDense(
        5,
        name='output',
        kernel_quantizer=quantized_bits(6, 0, alpha=1),
        bias_quantizer=quantized_bits(6, 0, alpha=1),
        kernel_initializer='lecun_uniform',
        kernel_regularizer=l1(0.0001),
    )
)
model.add(Activation(activation='softmax', name='softmax'))

# %% [markdown]
# ## Train sparse
# Let's train with model sparsity again, since QKeras layers are prunable.

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning

pruning_params = {"pruning_schedule": pruning_schedule.ConstantSparsity(0.75, begin_step=2000, frequency=100)}
model = prune.prune_low_magnitude(model, **pruning_params)

# %% [markdown]
# ## Train the model
# We'll use the same settings as the model for part 1: Adam optimizer with categorical crossentropy loss.
# The callbacks will decay the learning rate and save the model into a directory 'model_2'
# The model isn't very complex, so this should just take a few minutes even on the CPU.
# If you've restarted the notebook kernel after training once, set `train = False` to load the trained model rather than training again.

# %%
train = True
if train:
    adam = Adam(learning_rate=0.0001)
    model.compile(optimizer=adam, loss=['categorical_crossentropy'], metrics=['accuracy'])
    callbacks = all_callbacks(
        stop_patience=1000,
        lr_factor=0.5,
        lr_patience=10,
        lr_epsilon=0.000001,
        lr_cooldown=2,
        lr_minimum=0.0000001,
        outputDir='model_3',
    )
    callbacks.callbacks.append(pruning_callbacks.UpdatePruningStep())
    model.fit(
        X_train_val,
        y_train_val,
        batch_size=1024,
        epochs=30,
        validation_split=0.25,
        shuffle=True,
        callbacks=callbacks.callbacks,
    )
    # Save the model again but with the pruning 'stripped' to use the regular layer types
    model = strip_pruning(model)
    model.save('model_3/KERAS_check_best_model.h5')
else:
    from tensorflow.keras.models import load_model
    from qkeras.utils import _add_supported_quantized_objects

    co = {}
    _add_supported_quantized_objects(co)
    model = load_model('model_3/KERAS_check_best_model.h5', custom_objects=co)
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/30
# 486/487 [============================>.] - ETA: 0s - loss: 1.3722 - accuracy: 0.5088
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 1: val_loss improved from inf to 1.16007, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 1: val_loss improved from inf to 1.16007, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 1: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 1: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 1: saving model to model_3/KERAS_check_model_epoch01.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 10s 15ms/step - loss: 1.3720 - accuracy: 0.5089 - val_loss: 1.1601 - val_accuracy: 0.6181 - lr: 1.0000e-04
# Epoch 2/30
# 484/487 [============================>.] - ETA: 0s - loss: 1.0778 - accuracy: 0.6565
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 2: val_loss improved from 1.16007 to 1.01445, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 2: val_loss improved from 1.16007 to 1.01445, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 2: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 2: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 2: saving model to model_3/KERAS_check_model_epoch02.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 14ms/step - loss: 1.0775 - accuracy: 0.6566 - val_loss: 1.0145 - val_accuracy: 0.6884 - lr: 1.0000e-04
# Epoch 3/30
# 484/487 [============================>.] - ETA: 0s - loss: 0.9665 - accuracy: 0.7063
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 3: val_loss improved from 1.01445 to 0.92787, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 3: val_loss improved from 1.01445 to 0.92787, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 3: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 3: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 3: saving model to model_3/KERAS_check_model_epoch03.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 14ms/step - loss: 0.9663 - accuracy: 0.7063 - val_loss: 0.9279 - val_accuracy: 0.7150 - lr: 1.0000e-04
# Epoch 4/30
# 484/487 [============================>.] - ETA: 0s - loss: 0.8952 - accuracy: 0.7216
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 4: val_loss improved from 0.92787 to 0.87580, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 4: val_loss improved from 0.92787 to 0.87580, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 4: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 4: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 4: saving model to model_3/KERAS_check_model_epoch04.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 6s 13ms/step - loss: 0.8951 - accuracy: 0.7216 - val_loss: 0.8758 - val_accuracy: 0.7252 - lr: 1.0000e-04
# Epoch 5/30
# 483/487 [============================>.] - ETA: 0s - loss: 1.1107 - accuracy: 0.6706
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 5: val_loss did not improve from 0.87580
#
# Epoch 5: val_loss did not improve from 0.87580
#
# Epoch 5: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 5: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 5: saving model to model_3/KERAS_check_model_epoch05.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 13ms/step - loss: 1.1101 - accuracy: 0.6709 - val_loss: 1.0396 - val_accuracy: 0.7012 - lr: 1.0000e-04
# Epoch 6/30
# 486/487 [============================>.] - ETA: 0s - loss: 0.9926 - accuracy: 0.7078
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 6: val_loss did not improve from 0.87580
#
# Epoch 6: val_loss did not improve from 0.87580
#
# Epoch 6: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 6: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 6: saving model to model_3/KERAS_check_model_epoch06.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 6s 13ms/step - loss: 0.9926 - accuracy: 0.7078 - val_loss: 0.9570 - val_accuracy: 0.7144 - lr: 1.0000e-04
# Epoch 7/30
# 486/487 [============================>.] - ETA: 0s - loss: 0.9298 - accuracy: 0.7164
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 7: val_loss did not improve from 0.87580
#
# Epoch 7: val_loss did not improve from 0.87580
#
# Epoch 7: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 7: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 7: saving model to model_3/KERAS_check_model_epoch07.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 6s 13ms/step - loss: 0.9298 - accuracy: 0.7164 - val_loss: 0.9114 - val_accuracy: 0.7184 - lr: 1.0000e-04
# Epoch 8/30
# 487/487 [==============================] - ETA: 0s - loss: 0.8943 - accuracy: 0.7198
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 8: val_loss did not improve from 0.87580
#
# Epoch 8: val_loss did not improve from 0.87580
#
# Epoch 8: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 8: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 8: saving model to model_3/KERAS_check_model_epoch08.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 6s 13ms/step - loss: 0.8943 - accuracy: 0.7198 - val_loss: 0.8849 - val_accuracy: 0.7204 - lr: 1.0000e-04
# Epoch 9/30
# 484/487 [============================>.] - ETA: 0s - loss: 0.8720 - accuracy: 0.7216
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 9: val_loss improved from 0.87580 to 0.86589, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 9: val_loss improved from 0.87580 to 0.86589, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 9: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 9: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 9: saving model to model_3/KERAS_check_model_epoch09.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 6s 13ms/step - loss: 0.8719 - accuracy: 0.7216 - val_loss: 0.8659 - val_accuracy: 0.7221 - lr: 1.0000e-04
# Epoch 10/30
# 484/487 [============================>.] - ETA: 0s - loss: 0.8554 - accuracy: 0.7237
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 10: val_loss improved from 0.86589 to 0.85193, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 10: val_loss improved from 0.86589 to 0.85193, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 10: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 10: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 10: saving model to model_3/KERAS_check_model_epoch10.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 6s 13ms/step - loss: 0.8554 - accuracy: 0.7237 - val_loss: 0.8519 - val_accuracy: 0.7233 - lr: 1.0000e-04
# Epoch 11/30
# 482/487 [============================>.] - ETA: 0s - loss: 0.8431 - accuracy: 0.7249
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 11: val_loss improved from 0.85193 to 0.84087, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 11: val_loss improved from 0.85193 to 0.84087, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 11: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 11: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 11: saving model to model_3/KERAS_check_model_epoch11.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 14ms/step - loss: 0.8430 - accuracy: 0.7250 - val_loss: 0.8409 - val_accuracy: 0.7248 - lr: 1.0000e-04
# Epoch 12/30
# 483/487 [============================>.] - ETA: 0s - loss: 0.8326 - accuracy: 0.7263
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 12: val_loss improved from 0.84087 to 0.83154, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 12: val_loss improved from 0.84087 to 0.83154, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 12: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 12: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 12: saving model to model_3/KERAS_check_model_epoch12.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 6s 13ms/step - loss: 0.8326 - accuracy: 0.7263 - val_loss: 0.8315 - val_accuracy: 0.7269 - lr: 1.0000e-04
# Epoch 13/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.8233 - accuracy: 0.7282
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 13: val_loss improved from 0.83154 to 0.82229, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 13: val_loss improved from 0.83154 to 0.82229, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 13: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 13: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 13: saving model to model_3/KERAS_check_model_epoch13.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 15ms/step - loss: 0.8233 - accuracy: 0.7281 - val_loss: 0.8223 - val_accuracy: 0.7280 - lr: 1.0000e-04
# Epoch 14/30
# 487/487 [==============================] - ETA: 0s - loss: 0.8149 - accuracy: 0.7295
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 14: val_loss improved from 0.82229 to 0.81453, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 14: val_loss improved from 0.82229 to 0.81453, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 14: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 14: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 14: saving model to model_3/KERAS_check_model_epoch14.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 6s 13ms/step - loss: 0.8149 - accuracy: 0.7295 - val_loss: 0.8145 - val_accuracy: 0.7292 - lr: 1.0000e-04
# Epoch 15/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.8078 - accuracy: 0.7306
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 15: val_loss improved from 0.81453 to 0.80759, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 15: val_loss improved from 0.81453 to 0.80759, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 15: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 15: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 15: saving model to model_3/KERAS_check_model_epoch15.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 14ms/step - loss: 0.8078 - accuracy: 0.7306 - val_loss: 0.8076 - val_accuracy: 0.7307 - lr: 1.0000e-04
# Epoch 16/30
# 486/487 [============================>.] - ETA: 0s - loss: 0.8007 - accuracy: 0.7322
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 16: val_loss improved from 0.80759 to 0.80104, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 16: val_loss improved from 0.80759 to 0.80104, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 16: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 16: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 16: saving model to model_3/KERAS_check_model_epoch16.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 14ms/step - loss: 0.8007 - accuracy: 0.7322 - val_loss: 0.8010 - val_accuracy: 0.7324 - lr: 1.0000e-04
# Epoch 17/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.7943 - accuracy: 0.7339
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 17: val_loss improved from 0.80104 to 0.79514, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 17: val_loss improved from 0.80104 to 0.79514, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 17: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 17: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 17: saving model to model_3/KERAS_check_model_epoch17.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 14ms/step - loss: 0.7944 - accuracy: 0.7339 - val_loss: 0.7951 - val_accuracy: 0.7345 - lr: 1.0000e-04
# Epoch 18/30
# 486/487 [============================>.] - ETA: 0s - loss: 0.7885 - accuracy: 0.7352
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 18: val_loss improved from 0.79514 to 0.78939, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 18: val_loss improved from 0.79514 to 0.78939, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 18: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 18: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 18: saving model to model_3/KERAS_check_model_epoch18.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 14ms/step - loss: 0.7885 - accuracy: 0.7352 - val_loss: 0.7894 - val_accuracy: 0.7352 - lr: 1.0000e-04
# Epoch 19/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.7833 - accuracy: 0.7367
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 19: val_loss improved from 0.78939 to 0.78508, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 19: val_loss improved from 0.78939 to 0.78508, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 19: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 19: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 19: saving model to model_3/KERAS_check_model_epoch19.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 13ms/step - loss: 0.7832 - accuracy: 0.7367 - val_loss: 0.7851 - val_accuracy: 0.7366 - lr: 1.0000e-04
# Epoch 20/30
# 484/487 [============================>.] - ETA: 0s - loss: 0.7788 - accuracy: 0.7379
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 20: val_loss improved from 0.78508 to 0.78008, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 20: val_loss improved from 0.78508 to 0.78008, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 20: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 20: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 20: saving model to model_3/KERAS_check_model_epoch20.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 14ms/step - loss: 0.7786 - accuracy: 0.7380 - val_loss: 0.7801 - val_accuracy: 0.7381 - lr: 1.0000e-04
# Epoch 21/30
# 482/487 [============================>.] - ETA: 0s - loss: 0.7740 - accuracy: 0.7396
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 21: val_loss improved from 0.78008 to 0.77583, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 21: val_loss improved from 0.78008 to 0.77583, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 21: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 21: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 21: saving model to model_3/KERAS_check_model_epoch21.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 6s 13ms/step - loss: 0.7739 - accuracy: 0.7396 - val_loss: 0.7758 - val_accuracy: 0.7392 - lr: 1.0000e-04
# Epoch 22/30
# 484/487 [============================>.] - ETA: 0s - loss: 0.7703 - accuracy: 0.7408
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 22: val_loss improved from 0.77583 to 0.77186, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 22: val_loss improved from 0.77583 to 0.77186, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 22: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 22: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 22: saving model to model_3/KERAS_check_model_epoch22.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 14ms/step - loss: 0.7702 - accuracy: 0.7409 - val_loss: 0.7719 - val_accuracy: 0.7403 - lr: 1.0000e-04
# Epoch 23/30
# 482/487 [============================>.] - ETA: 0s - loss: 0.7663 - accuracy: 0.7423
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 23: val_loss improved from 0.77186 to 0.76897, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 23: val_loss improved from 0.77186 to 0.76897, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 23: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 23: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 23: saving model to model_3/KERAS_check_model_epoch23.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 14ms/step - loss: 0.7662 - accuracy: 0.7423 - val_loss: 0.7690 - val_accuracy: 0.7413 - lr: 1.0000e-04
# Epoch 24/30
# 481/487 [============================>.] - ETA: 0s - loss: 0.7629 - accuracy: 0.7431
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 24: val_loss improved from 0.76897 to 0.76526, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 24: val_loss improved from 0.76897 to 0.76526, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 24: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 24: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 24: saving model to model_3/KERAS_check_model_epoch24.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 14ms/step - loss: 0.7631 - accuracy: 0.7431 - val_loss: 0.7653 - val_accuracy: 0.7419 - lr: 1.0000e-04
# Epoch 25/30
# 482/487 [============================>.] - ETA: 0s - loss: 0.7600 - accuracy: 0.7443
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 25: val_loss improved from 0.76526 to 0.76263, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 25: val_loss improved from 0.76526 to 0.76263, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 25: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 25: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 25: saving model to model_3/KERAS_check_model_epoch25.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 6s 13ms/step - loss: 0.7599 - accuracy: 0.7443 - val_loss: 0.7626 - val_accuracy: 0.7430 - lr: 1.0000e-04
# Epoch 26/30
# 484/487 [============================>.] - ETA: 0s - loss: 0.7573 - accuracy: 0.7448
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 26: val_loss improved from 0.76263 to 0.76092, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 26: val_loss improved from 0.76263 to 0.76092, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 26: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 26: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 26: saving model to model_3/KERAS_check_model_epoch26.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 14ms/step - loss: 0.7574 - accuracy: 0.7448 - val_loss: 0.7609 - val_accuracy: 0.7433 - lr: 1.0000e-04
# Epoch 27/30
# 483/487 [============================>.] - ETA: 0s - loss: 0.7552 - accuracy: 0.7456
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 27: val_loss improved from 0.76092 to 0.75807, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 27: val_loss improved from 0.76092 to 0.75807, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 27: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 27: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 27: saving model to model_3/KERAS_check_model_epoch27.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 6s 13ms/step - loss: 0.7553 - accuracy: 0.7456 - val_loss: 0.7581 - val_accuracy: 0.7448 - lr: 1.0000e-04
# Epoch 28/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.7529 - accuracy: 0.7462
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 28: val_loss improved from 0.75807 to 0.75630, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 28: val_loss improved from 0.75807 to 0.75630, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 28: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 28: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 28: saving model to model_3/KERAS_check_model_epoch28.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 6s 13ms/step - loss: 0.7528 - accuracy: 0.7463 - val_loss: 0.7563 - val_accuracy: 0.7455 - lr: 1.0000e-04
# Epoch 29/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.7510 - accuracy: 0.7471
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 29: val_loss improved from 0.75630 to 0.75449, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 29: val_loss improved from 0.75630 to 0.75449, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 29: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 29: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 29: saving model to model_3/KERAS_check_model_epoch29.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 7s 14ms/step - loss: 0.7510 - accuracy: 0.7471 - val_loss: 0.7545 - val_accuracy: 0.7456 - lr: 1.0000e-04
# Epoch 30/30
# 484/487 [============================>.] - ETA: 0s - loss: 0.7490 - accuracy: 0.7478
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 30: val_loss improved from 0.75449 to 0.75233, saving model to model_3/KERAS_check_best_model.keras
#
# Epoch 30: val_loss improved from 0.75449 to 0.75233, saving model to model_3/KERAS_check_best_model.weights.h5
#
# Epoch 30: saving model to model_3/KERAS_check_model_last.keras
#
# Epoch 30: saving model to model_3/KERAS_check_model_last.weights.h5
#
# Epoch 30: saving model to model_3/KERAS_check_model_epoch30.keras
#
# ***callbacks end***
#
# 487/487 [==============================] - 6s 13ms/step - loss: 0.7490 - accuracy: 0.7478 - val_loss: 0.7523 - val_accuracy: 0.7470 - lr: 1.0000e-04
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## Check performance
# How does this model which was trained using 6-bits, and 75% sparsity model compare against the original model? Let's report the accuracy and make a ROC curve. The quantized, pruned model is shown with solid lines, the unpruned model from part 1 is shown with dashed lines.
#
#
# We should also check that hls4ml can respect the choice to use 6-bits throughout the model, and match the accuracy. We'll generate a configuration from this Quantized model, and plot its performance as the dotted line.
# The generated configuration is printed out. You'll notice that it uses 7 bits for the type, but we specified 6!? That's just because QKeras doesn't count the sign-bit when we specify the number of bits, so the type that actually gets used needs 1 more.
#
# We also use the `OutputRoundingSaturationMode` optimizer pass of `hls4ml` to set the Activation layers to round, rather than truncate, the cast. This is important for getting good model accuracy when using small bit precision activations. And we'll set a different data type for the tables used in the Softmax, just for a bit of extra performance.
#
#
# **Make sure you've trained the model from part 1**

# %%
import hls4ml
import plotting

config = hls4ml.utils.config_from_keras_model(model, granularity='name')
config['LayerName']['softmax']['exp_table_t'] = 'ap_fixed<18,8>'
config['LayerName']['softmax']['inv_table_t'] = 'ap_fixed<18,4>'
print("-----------------------------------")
plotting.print_dict(config)
print("-----------------------------------")
hls_model = hls4ml.converters.convert_from_keras_model(
    model, hls_config=config, backend='Vivado', output_dir='model_3/hls4ml_prj', part='xcu250-figd2104-2L-e'
)
hls_model.compile()

y_qkeras = model.predict(np.ascontiguousarray(X_test))
y_hls = hls_model.predict(np.ascontiguousarray(X_test))
np.save('model_3/y_qkeras.npy', y_qkeras)
np.save('model_3/y_hls.npy', y_hls)
# Out:
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: Input
# Layer name: fc1, layer type: QDense
# Layer name: relu1, layer type: QActivation
# Layer name: fc2, layer type: QDense
# Layer name: relu2, layer type: QActivation
# Layer name: fc3, layer type: QDense
# Layer name: relu3, layer type: QActivation
# Layer name: output, layer type: QDense
# Layer name: softmax, layer type: Activation
# -----------------------------------
# Model
#   Precision:         ap_fixed<16,6>
#   ReuseFactor:       1
#   Strategy:          Latency
# LayerName
#   fc1_input
#     Precision
#       result:        ap_fixed<16,6>
#   fc1
#     Precision
#       weight:        ap_fixed<6,1>
#       bias:          ap_fixed<6,1>
#     ReuseFactor:     1
#   relu1
#     Precision
#       result:        ap_ufixed<6,0>
#     ReuseFactor:     1
#   fc2
#     Precision
#       weight:        ap_fixed<6,1>
#       bias:          ap_fixed<6,1>
#     ReuseFactor:     1
#   relu2
#     Precision
#       result:        ap_ufixed<6,0>
#     ReuseFactor:     1
#   fc3
#     Precision
#       weight:        ap_fixed<6,1>
#       bias:          ap_fixed<6,1>
#     ReuseFactor:     1
#   relu3
#     Precision
#       result:        ap_ufixed<6,0>
#     ReuseFactor:     1
#   output
#     Precision
#       weight:        ap_fixed<6,1>
#       bias:          ap_fixed<6,1>
#     ReuseFactor:     1
#   softmax
#     Precision:       ap_fixed<16,6>
#     ReuseFactor:     1
#     table_size:      1024
#     exp_table_t:     ap_fixed<18,8>
#     inv_table_t:     ap_fixed<18,4>
# -----------------------------------
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: InputLayer, input shapes: [[None, 16]], output shape: [None, 16]
# Layer name: fc1, layer type: QDense, input shapes: [[None, 16]], output shape: [None, 64]
# Layer name: relu1, layer type: Activation, input shapes: [[None, 64]], output shape: [None, 64]
# Layer name: fc2, layer type: QDense, input shapes: [[None, 64]], output shape: [None, 32]
# Layer name: relu2, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: fc3, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: relu3, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: output, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 5]
# Layer name: softmax, layer type: Softmax, input shapes: [[None, 5]], output shape: [None, 5]
# Creating HLS model
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done
# 5188/5188 [==============================] - 10s 2ms/step

# %%
# %matplotlib inline
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model

model_ref = load_model('model_1/KERAS_check_best_model.keras')
y_ref = model_ref.predict(X_test)

print("Accuracy baseline:  {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_ref, axis=1))))
print("Accuracy pruned, quantized: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_qkeras, axis=1))))
print("Accuracy hls4ml: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_hls, axis=1))))

fig, ax = plt.subplots(figsize=(9, 9))
_ = plotting.makeRoc(y_test, y_ref, classes)
plt.gca().set_prop_cycle(None)  # reset the colors
_ = plotting.makeRoc(y_test, y_qkeras, classes, linestyle='--')
plt.gca().set_prop_cycle(None)  # reset the colors
_ = plotting.makeRoc(y_test, y_hls, classes, linestyle=':')

from matplotlib.lines import Line2D

lines = [Line2D([0], [0], ls='-'), Line2D([0], [0], ls='--'), Line2D([0], [0], ls=':')]
from matplotlib.legend import Legend

leg = Legend(ax, lines, labels=['baseline', 'pruned, quantized', 'hls4ml'], loc='lower right', frameon=False)
ax.add_artist(leg)
plt.show()
# Out:
# 5188/5188 [==============================] - 6s 1ms/step
# Accuracy baseline:  0.7367831325301205
# Accuracy pruned, quantized: 0.746078313253012
# Accuracy hls4ml: 0.6287530120481928

# %% [markdown]
# ## Synthesize
# Now let's synthesize this quantized, pruned model.
#
# **The synthesis will take a while**
#
# While the C-Synthesis is running, we can monitor the progress looking at the log file by opening a terminal from the notebook home, and executing:
#
# `tail -f model_3/hls4ml_prj/vitis_hls.log`

# %%
hls_model.build(csim=False)
# Out:
# ****** Vivado(TM) HLS - High-Level Synthesis from C, C++ and SystemC v2019.1 (64-bit)
#   **** SW Build 2552052 on Fri May 24 14:47:09 MDT 2019
#   **** IP Build 2548770 on Fri May 24 18:01:18 MDT 2019
#     ** Copyright 1986-2019 Xilinx, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vivado/2019.1/scripts/vivado_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/tools/Xilinx/Vivado/2019.1/bin/unwrapped/lnx64.o/vivado_hls'
# INFO: [HLS 200-10] For user 'chanssen' on host 'hvm1' (Linux_x86_64 version 5.15.0-157-generic) on Tue Oct 14 21:57:19 PDT 2025
# INFO: [HLS 200-10] On os Ubuntu 22.04.5 LTS
# INFO: [HLS 200-10] In directory '/home/chanssen/HLS4ML_VS_MANUAL/documents/hls4ml-tutorial-modified/model_3/hls4ml_prj'
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-10] Creating and opening project '/home/chanssen/HLS4ML_VS_MANUAL/documents/hls4ml-tutorial-modified/model_3/hls4ml_prj/myproject_prj'.
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-10] Creating and opening solution '/home/chanssen/HLS4ML_VS_MANUAL/documents/hls4ml-tutorial-modified/model_3/hls4ml_prj/myproject_prj/solution1'.
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# INFO: [XFORM 203-1161] The maximum of name length is set into 60.
# ERROR: [HLS 200-70] Part 'xcu250-figd2104-2L-e' is not installed.
# command 'ap_source' returned error code
#     while executing
# "source build_prj.tcl"
#     ("uplevel" body line 1)
#     invoked from within
# "uplevel \#0 [list source $arg] "
#
# INFO: [Common 17-206] Exiting vivado_hls at Tue Oct 14 21:57:21 2025...
# Synthesis report not found.
# {}

# %% [markdown]
# ## Check the reports
# Print out the reports generated by Vitis HLS. Pay attention to the Utilization Estimates' section in particular this time.

# %%
hls4ml.report.read_vivado_report('model_3/hls4ml_prj')
# Out:
# Found 1 solution(s) in model_3/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# Synthesis report not found.
# Co-simulation report not found.

# %% [markdown]
# Print the report for the model trained in part 1. Now, compared to the model from part 1, this model has been trained with low-precision quantization, and 75% pruning. You should be able to see that we have saved a lot of resource compared to where we started in part 1. At the same time, referring to the ROC curve above, the model performance is pretty much identical even with this drastic compression!
#
# **Note you need to have trained and synthesized the model from part 1**

# %%
hls4ml.report.read_vivado_report('model_1/hls4ml_prj')
# Out:
# Found 1 solution(s) in model_1/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject'
# ================================================================
# * Date:           Thu Oct  9 23:38:28 2025
#
# * Version:        2019.1 (Build 2552052 on Fri May 24 15:28:33 MDT 2019)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: virtex7
# * Target device:  xc7vx690t-ffg1761-2
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing (ns):
#     * Summary:
#     +--------+-------+----------+------------+
#     |  Clock | Target| Estimated| Uncertainty|
#     +--------+-------+----------+------------+
#     |ap_clk  |   5.00|     4.890|        0.62|
#     +--------+-------+----------+------------+
#
# + Latency (clock cycles):
#     * Summary:
#     +-----+-----+-----+-----+----------+
#     |  Latency  |  Interval | Pipeline |
#     | min | max | min | max |   Type   |
#     +-----+-----+-----+-----+----------+
#     |   27|   27|    1|    1| function |
#     +-----+-----+-----+-----+----------+
#
#     + Detail:
#         * Instance:
#         +--------------------------------------------------------------------------+---------------------------------------------------------------+-----+-----+-----+-----+----------+
#         |                                                                          |                                                               |  Latency  |  Interval | Pipeline |
#         |                                 Instance                                 |                             Module                            | min | max | min | max |   Type   |
#         +--------------------------------------------------------------------------+---------------------------------------------------------------+-----+-----+-----+-----+----------+
#         |grp_dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_1_fu_123  |dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_1  |    3|    3|    1|    1| function |
#         |grp_dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_2_fu_191  |dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_2  |    3|    3|    1|    1| function |
#         |grp_dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_s_fu_197  |dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_s  |    3|    3|    1|    1| function |
#         |grp_dense_latency_ap_fixed_ap_fixed_config11_0_0_0_0_0_0_fu_233           |dense_latency_ap_fixed_ap_fixed_config11_0_0_0_0_0_0           |    3|    3|    1|    1| function |
#         |call_ret1_relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config4_s_fu_269         |relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config4_s               |    0|    0|    1|    1| function |
#         |call_ret3_relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config7_s_fu_337         |relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config7_s               |    0|    0|    1|    1| function |
#         |call_ret5_relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config10_s_fu_373        |relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config10_s              |    0|    0|    1|    1| function |
#         |grp_softmax_latency_ap_fixed_ap_fixed_softmax_config13_s_fu_409           |softmax_latency_ap_fixed_ap_fixed_softmax_config13_s           |    5|    5|    1|    1| function |
#         +--------------------------------------------------------------------------+---------------------------------------------------------------+-----+-----+-----+-----+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +-----------------+---------+-------+--------+--------+-----+
# |       Name      | BRAM_18K| DSP48E|   FF   |   LUT  | URAM|
# +-----------------+---------+-------+--------+--------+-----+
# |DSP              |        -|      -|       -|       -|    -|
# |Expression       |        -|      -|       0|       6|    -|
# |FIFO             |        -|      -|       -|       -|    -|
# |Instance         |        4|   2962|   78995|  131490|    -|
# |Memory           |        -|      -|       -|       -|    -|
# |Multiplexer      |        -|      -|       -|      36|    -|
# |Register         |        -|      -|    4382|       -|    -|
# +-----------------+---------+-------+--------+--------+-----+
# |Total            |        4|   2962|   83377|  131532|    0|
# +-----------------+---------+-------+--------+--------+-----+
# |Available        |     2940|   3600|  866400|  433200|    0|
# +-----------------+---------+-------+--------+--------+-----+
# |Utilization (%)  |    ~0   |     82|       9|      30|    0|
# +-----------------+---------+-------+--------+--------+-----+
#
# + Detail:
#     * Instance:
#     +--------------------------------------------------------------------------+---------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |                                 Instance                                 |                             Module                            | BRAM_18K| DSP48E|   FF  |  LUT  | URAM|
#     +--------------------------------------------------------------------------+---------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |grp_dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_1_fu_123  |dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_1  |        0|   1322|  36712|  62924|    0|
#     |grp_dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_2_fu_191  |dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_2  |        0|    824|  19796|  30331|    0|
#     |grp_dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_s_fu_197  |dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_s  |        0|    686|  18246|  29935|    0|
#     |grp_dense_latency_ap_fixed_ap_fixed_config11_0_0_0_0_0_0_fu_233           |dense_latency_ap_fixed_ap_fixed_config11_0_0_0_0_0_0           |        0|    125|   3663|   4478|    0|
#     |call_ret5_relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config10_s_fu_373        |relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config10_s              |        0|      0|      0|    896|    0|
#     |call_ret1_relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config4_s_fu_269         |relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config4_s               |        0|      0|      0|   1792|    0|
#     |call_ret3_relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config7_s_fu_337         |relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config7_s               |        0|      0|      0|    896|    0|
#     |grp_softmax_latency_ap_fixed_ap_fixed_softmax_config13_s_fu_409           |softmax_latency_ap_fixed_ap_fixed_softmax_config13_s           |        4|      5|    578|    238|    0|
#     +--------------------------------------------------------------------------+---------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |Total                                                                     |                                                               |        4|   2962|  78995| 131490|    0|
#     +--------------------------------------------------------------------------+---------------------------------------------------------------+---------+-------+-------+-------+-----+
#
# Co-simulation report not found.

# %% [markdown]
# Print the report for the model trained in part 3. Both these models were trained with 75% sparsity, but the new model uses 6-bit precision as well. You can see how Vitis HLS has moved multiplication operations from DSPs into LUTs, reducing the "critical" resource usage.
#
# **Note you need to have trained and synthesized the model from part 3**

# %%
hls4ml.report.read_vivado_report('model_2/hls4ml_prj')
# Out:
# Found 1 solution(s) in model_2/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject'
# ================================================================
# * Date:           Mon Oct 13 16:23:56 2025
#
# * Version:        2019.1 (Build 2552052 on Fri May 24 15:28:33 MDT 2019)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: virtex7
# * Target device:  xc7vx690t-ffg1761-2
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing (ns):
#     * Summary:
#     +--------+-------+----------+------------+
#     |  Clock | Target| Estimated| Uncertainty|
#     +--------+-------+----------+------------+
#     |ap_clk  |   5.00|     4.890|        0.62|
#     +--------+-------+----------+------------+
#
# + Latency (clock cycles):
#     * Summary:
#     +-----+-----+-----+-----+----------+
#     |  Latency  |  Interval | Pipeline |
#     | min | max | min | max |   Type   |
#     +-----+-----+-----+-----+----------+
#     |   24|   24|    1|    1| function |
#     +-----+-----+-----+-----+----------+
#
#     + Detail:
#         * Instance:
#         +--------------------------------------------------------------------------+---------------------------------------------------------------+-----+-----+-----+-----+----------+
#         |                                                                          |                                                               |  Latency  |  Interval | Pipeline |
#         |                                 Instance                                 |                             Module                            | min | max | min | max |   Type   |
#         +--------------------------------------------------------------------------+---------------------------------------------------------------+-----+-----+-----+-----+----------+
#         |grp_dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_1_fu_123  |dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_1  |    2|    2|    1|    1| function |
#         |grp_dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_2_fu_191  |dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_2  |    2|    2|    1|    1| function |
#         |grp_dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_s_fu_197  |dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_s  |    2|    2|    1|    1| function |
#         |grp_dense_latency_ap_fixed_ap_fixed_config11_0_0_0_0_0_0_fu_232           |dense_latency_ap_fixed_ap_fixed_config11_0_0_0_0_0_0           |    2|    2|    1|    1| function |
#         |call_ret1_relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config4_s_fu_258         |relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config4_s               |    0|    0|    1|    1| function |
#         |call_ret3_relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config7_s_fu_326         |relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config7_s               |    0|    0|    1|    1| function |
#         |call_ret5_relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config10_s_fu_361        |relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config10_s              |    0|    0|    1|    1| function |
#         |grp_softmax_latency_ap_fixed_ap_fixed_softmax_config13_s_fu_387           |softmax_latency_ap_fixed_ap_fixed_softmax_config13_s           |    5|    5|    1|    1| function |
#         +--------------------------------------------------------------------------+---------------------------------------------------------------+-----+-----+-----+-----+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +-----------------+---------+-------+--------+--------+-----+
# |       Name      | BRAM_18K| DSP48E|   FF   |   LUT  | URAM|
# +-----------------+---------+-------+--------+--------+-----+
# |DSP              |        -|      -|       -|       -|    -|
# |Expression       |        -|      -|       0|       6|    -|
# |FIFO             |        -|      -|       -|       -|    -|
# |Instance         |        4|    872|   23596|   33747|    -|
# |Memory           |        -|      -|       -|       -|    -|
# |Multiplexer      |        -|      -|       -|      36|    -|
# |Register         |        -|      -|    4107|       -|    -|
# +-----------------+---------+-------+--------+--------+-----+
# |Total            |        4|    872|   27703|   33789|    0|
# +-----------------+---------+-------+--------+--------+-----+
# |Available        |     2940|   3600|  866400|  433200|    0|
# +-----------------+---------+-------+--------+--------+-----+
# |Utilization (%)  |    ~0   |     24|       3|       7|    0|
# +-----------------+---------+-------+--------+--------+-----+
#
# + Detail:
#     * Instance:
#     +--------------------------------------------------------------------------+---------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |                                 Instance                                 |                             Module                            | BRAM_18K| DSP48E|   FF  |  LUT  | URAM|
#     +--------------------------------------------------------------------------+---------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |grp_dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_1_fu_123  |dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_1  |        0|    410|  10845|  15130|    0|
#     |grp_dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_2_fu_191  |dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_2  |        0|    236|   5788|   7459|    0|
#     |grp_dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_s_fu_197  |dense_latency_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_s  |        0|    183|   5106|   6525|    0|
#     |grp_dense_latency_ap_fixed_ap_fixed_config11_0_0_0_0_0_0_fu_232           |dense_latency_ap_fixed_ap_fixed_config11_0_0_0_0_0_0           |        0|     38|   1279|   1119|    0|
#     |call_ret5_relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config10_s_fu_361        |relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config10_s              |        0|      0|      0|    616|    0|
#     |call_ret1_relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config4_s_fu_258         |relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config4_s               |        0|      0|      0|   1792|    0|
#     |call_ret3_relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config7_s_fu_326         |relu_ap_fixed_ap_fixed_16_6_5_3_0_relu_config7_s               |        0|      0|      0|    868|    0|
#     |grp_softmax_latency_ap_fixed_ap_fixed_softmax_config13_s_fu_387           |softmax_latency_ap_fixed_ap_fixed_softmax_config13_s           |        4|      5|    578|    238|    0|
#     +--------------------------------------------------------------------------+---------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |Total                                                                     |                                                               |        4|    872|  23596|  33747|    0|
#     +--------------------------------------------------------------------------+---------------------------------------------------------------+---------+-------+-------+-------+-----+
#
# Co-simulation report not found.

# %% [markdown]
# ## NB
# Note as well that the Vitis HLS resource estimates tend to _overestimate_ LUTs, while generally estimating the DSPs correctly. Running the subsequent stages of FPGA compilation reveals the more realistic resource usage, You can run the next step, 'logic synthesis' with `hls_model.build(synth=True, vsynth=True)`, but we skipped it in this tutorial in the interest of time.
